# %%
#Import all relevant libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
 
# ## This statement allows the visuals to render within your Jupyter Notebook.
# %matplotlib inline

# %% [markdown]
# ## Loading the data
# We can now load the dataset into pandas using the read_csv() function. This converts the CSV file into a Pandas dataframe.

# %%
#Read in the csv file and convert to a Pandas dataframe
world_happiness_2015 = pd.read_csv("D:/Documents/Downloads/week2_lap3 tuwiq/Usecase-2-Mushal/2015.csv")
world_happiness_2016 = pd.read_csv("D:/Documents/Downloads/week2_lap3 tuwiq/Usecase-2-Mushal/2016.csv")
world_happiness_2017 = pd.read_csv("D:/Documents/Downloads/week2_lap3 tuwiq/Usecase-2-Mushal/2017.csv")
world_happiness_2018 = pd.read_csv("D:/Documents/Downloads/week2_lap3 tuwiq/Usecase-2-Mushal/2018.csv")
world_happiness_2019 = pd.read_csv("D:/Documents/Downloads/week2_lap3 tuwiq/Usecase-2-Mushal/2019.csv")

# %% [markdown]
# ### Viewing the dataframe
# We can get a quick sense of the size of our dataset by using the shape method. This returns a tuple with the number of rows and columns in the dataset.

# %% [markdown]
# # world_happiness_2015 dataset

# %%
world_happiness_2015.head(3)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204

# %%
world_happiness_2015.shape
# Out:
# (158, 12)

# %% [markdown]
# # world_happiness_2016 dataset

# %%
world_happiness_2016.head(3)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# ...

# %%
world_happiness_2016.shape
# Out:
# (157, 13)

# %% [markdown]
# # world_happiness_2017 dataset

# %%
world_happiness_2017.head(3)
# Out:
#    Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0   Norway               1            7.537      7.594445     7.479556
# 1  Denmark               2            7.522      7.581728     7.462272
# 2  Iceland               3            7.504      7.622030     7.385970
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707
# 2    0.475540                       0.153527           2.322715

# %%
world_happiness_2017.shape
# Out:
# (155, 12)

# %% [markdown]
# # world_happiness_2018 dataset

# %%
world_happiness_2018.head(3)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# 2                      0.408

# %%
world_happiness_2018.shape
# Out:
# (156, 9)

# %% [markdown]
# # world_happiness_2019 dataset

# %%
world_happiness_2019.head(3)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341

# %%
world_happiness_2019.shape
# Out:
# (156, 9)

# %% [markdown]
# ## 1. Data Profiling:
# Data profiling is a comprehensive process of examining the data available in an existing dataset and collecting statistics and information about that data.

# %%
world_happiness_2015.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
world_happiness_2016.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
world_happiness_2017.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
world_happiness_2018.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
world_happiness_2019.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
world_happiness_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
world_happiness_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
#  6   Economy (GDP per Capita)       157 non-null    float64
#  7   Family                         157 non-null    float64
#  8   Health (Life Expectancy)       157 non-null    float64
#  9   Freedom                        157 non-null    float64
#  10  Trust (Government Corruption)  157 non-null    float64
#  11  Generosity                     157 non-null    float64
# ...

# %%
world_happiness_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness.Rank                 155 non-null    int64
#  2   Happiness.Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy..GDP.per.Capita.       155 non-null    float64
#  6   Family                         155 non-null    float64
#  7   Health..Life.Expectancy.       155 non-null    float64
#  8   Freedom                        155 non-null    float64
#  9   Generosity                     155 non-null    float64
#  10  Trust..Government.Corruption.  155 non-null    float64
#  11  Dystopia.Residual              155 non-null    float64
# ...

# %%
world_happiness_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     155 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
world_happiness_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
world_happiness_2015.describe(include='number')
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
world_happiness_2015.describe(include='object')
# Out:
#             Country              Region
# count           158                 158
# unique          158                  10
# top     Switzerland  Sub-Saharan Africa
# freq              1                  40

# %%
world_happiness_2016.describe(include='number')
# Out:
#        Happiness Rank  Happiness Score  Lower Confidence Interval  \
# count      157.000000       157.000000                 157.000000
# mean        78.980892         5.382185                   5.282395
# std         45.466030         1.141674                   1.148043
# min          1.000000         2.905000                   2.732000
# 25%         40.000000         4.404000                   4.327000
# 50%         79.000000         5.314000                   5.237000
# 75%        118.000000         6.269000                   6.154000
# max        157.000000         7.526000                   7.460000
#
#        Upper Confidence Interval  Economy (GDP per Capita)      Family  \
# count                 157.000000                157.000000  157.000000
# mean                    5.481975                  0.953880    0.793621
# std                     1.136493                  0.412595    0.266706
# min                     3.078000                  0.000000    0.000000
# ...

# %%
world_happiness_2016.describe(include='object')
# Out:
#         Country              Region
# count       157                 157
# unique      157                  10
# top     Denmark  Sub-Saharan Africa
# freq          1                  38

# %%
world_happiness_2017.describe(include='number')
# Out:
#        Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# count      155.000000       155.000000    155.000000   155.000000
# mean        78.000000         5.354019      5.452326     5.255713
# std         44.888751         1.131230      1.118542     1.145030
# min          1.000000         2.693000      2.864884     2.521116
# 25%         39.500000         4.505500      4.608172     4.374955
# 50%         78.000000         5.279000      5.370032     5.193152
# 75%        116.500000         6.101500      6.194600     6.006527
# max        155.000000         7.537000      7.622030     7.479556
#
#        Economy..GDP.per.Capita.      Family  Health..Life.Expectancy.  \
# count                155.000000  155.000000                155.000000
# mean                   0.984718    1.188898                  0.551341
# std                    0.420793    0.287263                  0.237073
# min                    0.000000    0.000000                  0.000000
# ...

# %%
world_happiness_2017.describe(include='object')
# Out:
#        Country
# count      155
# unique     155
# top     Norway
# freq         1

# %%
world_happiness_2018.describe(include='number')
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.375917        0.891449        1.213237
# std       45.177428    1.119506        0.391921        0.302372
# min        1.000000    2.905000        0.000000        0.000000
# 25%       39.750000    4.453750        0.616250        1.066750
# 50%       78.500000    5.378000        0.949500        1.255000
# 75%      117.250000    6.168500        1.197750        1.463000
# max      156.000000    7.632000        2.096000        1.644000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.597346                      0.454506    0.181006
# std                   0.247579                      0.162424    0.098471
# min                   0.000000                      0.000000    0.000000
# ...

# %%
world_happiness_2018.describe(include='object')
# Out:
#        Country or region
# count                156
# unique               156
# top              Finland
# freq                   1

# %%
world_happiness_2019.describe(include='number')
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# ...

# %%
world_happiness_2019.describe(include='object')
# Out:
#        Country or region
# count                156
# unique               156
# top              Finland
# freq                   1

# %%
world_happiness_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
world_happiness_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
world_happiness_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
world_happiness_2018.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
world_happiness_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %% [markdown]
# The process of profiling differs slightly for categorical and numerical variables due to their inherent differences.
#
# **The two main types of data are:**
# - Quantitative (numerical) data
# - Qualitative (categorical) data

# %% [markdown]
# ### Data Quality Checks
# Data quality checks involve the process of ensuring that the data is accurate, complete, consistent, relevant, and reliable.
#
#
# **Here are typical steps involved in checking data quality:**

# %% [markdown]
# #### 1. Reliability:
# Evaluate the data's source and collection process to determine its trustworthiness.

# %%
#The dataset is sourced from the reputable Gallup World Poll, World Values Survey,
#and official statistics from the World Bank and United Nations, ensuring its reliability.

# %% [markdown]
# #### 2. Timeliness:
# Ensure the data is up-to-date and reflective of the current situation or the period of interest for the analysis.

# %%
# data is exist for 2015 till 2019 for world happiness

# %% [markdown]
# #### 3. Consistency:
#
# Confirm that the data is consistent within the dataset and across multiple data sources. For example, the same data point should not have different values in different places.

# %%
# consistence

# %% [markdown]
# #### 4. Relevance:
# Assess whether the data is appropriate and applicable for the intended analysis. Data that is not relevant can skew results and lead to incorrect conclusions.
#
# **Key considerations for relevance include:**
#
# > 1. Sample Appropriateness: Confirm that your data sample aligns with your analysis objectives. For instance, utilizing data from the Northern region will not yield accurate insights for the Western region of the Kingdom.
# >
# > 2. Variable Selection: Any column will not be relevant for our analysis, we can get rid of these using the drop() method. We will set the “axis” argument to 1 since we’re dealing with columns, and set the “inplace” argument to True to make the change permanent.

# %%
world_happiness_2015.head(2)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201

# %%
world_happiness_2016.head(2)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# 1                        0.41203     0.28083            2.69463

# %%
world_happiness_2017.head(2)
# Out:
#    Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0   Norway               1            7.537      7.594445     7.479556
# 1  Denmark               2            7.522      7.581728     7.462272
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707

# %%
world_happiness_2018.head(2)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340

# %%
world_happiness_2019.head(2)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410

# %%
print(world_happiness_2015['Region'].unique())
# Out:
# ['Western Europe' 'North America' 'Australia and New Zealand'
#  'Middle East and Northern Africa' 'Latin America and Caribbean'
#  'Southeastern Asia' 'Central and Eastern Europe' 'Eastern Asia'
#  'Sub-Saharan Africa' 'Southern Asia']

# %%
world_happiness_2015[world_happiness_2015.duplicated(['Country'])]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Standard Error, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
world_happiness_2016[world_happiness_2016.duplicated(['Country'])]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Lower Confidence Interval, Upper Confidence Interval, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
world_happiness_2017[world_happiness_2017.duplicated(['Country'])]
# Out:
# Empty DataFrame
# Columns: [Country, Happiness.Rank, Happiness.Score, Whisker.high, Whisker.low, Economy..GDP.per.Capita., Family, Health..Life.Expectancy., Freedom, Generosity, Trust..Government.Corruption., Dystopia.Residual]
# Index: []

# %%
world_happiness_2018[world_happiness_2018.duplicated(['Country or region'])]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %%
world_happiness_2019[world_happiness_2019.duplicated(['Country or region'])]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %% [markdown]
# #### 5. Uniqueness:
# Check for and remove duplicate records to prevent skewed analysis results.

# %% [markdown]
# # world_happiness_2015 dataset

# %%
world_happiness_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
world_happiness_2015.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
# check number of row duplicate
world_happiness_2015.duplicated().sum()
# Out:
# np.int64(0)

# %%
rows_with_dash = world_happiness_2015[(world_happiness_2015 == '-').any(axis=1)]
rows_with_dash
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Standard Error, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
# Count occurrences of '-' in each column
dash_counts = (world_happiness_2015 == '-').sum()
dash_counts
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
world_happiness_2015[world_happiness_2015.duplicated(['Happiness Rank'])]
# Out:
#        Country                      Region  Happiness Rank  Happiness Score  \
# 82  Montenegro  Central and Eastern Europe              82            5.192
#
#     Standard Error  Economy (GDP per Capita)   Family  \
# 82         0.05235                   0.97438  0.90557
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 82                   0.72521   0.1826                        0.14296
#
#     Generosity  Dystopia Residual
# 82      0.1614            2.10017

# %%
duplicated_rank = world_happiness_2015[world_happiness_2015.duplicated(['Happiness Rank'], keep=False)]
duplicated_rank
# Out:
#        Country                           Region  Happiness Rank  \
# 81      Jordan  Middle East and Northern Africa              82
# 82  Montenegro       Central and Eastern Europe              82
#
#     Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 81            5.192         0.04524                   0.90198  1.05392
# 82            5.192         0.05235                   0.97438  0.90557
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 81                   0.69639  0.40661                        0.14293
# 82                   0.72521  0.18260                        0.14296
#
#     Generosity  Dystopia Residual
# 81     0.11053            1.87996
# 82     0.16140            2.10017

# %%
expected_ranks = set(range(1, 159))
actual_ranks = set(world_happiness_2015['Happiness Rank'])
missing_ranks = sorted(expected_ranks - actual_ranks)
print("Missing Ranks", missing_ranks)
# Out:
# Missing Ranks [83]

# %%
world_happiness_2015.loc[world_happiness_2015['Country'] == 'Montenegro', 'Happiness Rank'] = 83

# %%
duplicated_rows = world_happiness_2015[world_happiness_2015.duplicated(['Happiness Rank'], keep=False)]
duplicated_rows
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Standard Error, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
duplicated_rows = world_happiness_2015[world_happiness_2015.duplicated(['Happiness Score'], keep=False)]
duplicated_rows
# Out:
#        Country                           Region  Happiness Rank  \
# 81      Jordan  Middle East and Northern Africa              82
# 82  Montenegro       Central and Eastern Europe              83
#
#     Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 81            5.192         0.04524                   0.90198  1.05392
# 82            5.192         0.05235                   0.97438  0.90557
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 81                   0.69639  0.40661                        0.14293
# 82                   0.72521  0.18260                        0.14296
#
#     Generosity  Dystopia Residual
# 81     0.11053            1.87996
# 82     0.16140            2.10017

# %% [markdown]
# # world_happiness_2016 dataset

# %%
world_happiness_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
world_happiness_2016.tail()
# Out:
#          Country                           Region  Happiness Rank  \
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 152            3.484                      3.404                      3.564
# 153            3.360                      3.288                      3.432
# 154            3.303                      3.192                      3.414
# 155            3.069                      2.936                      3.202
# 156            2.905                      2.732                      3.078
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
world_happiness_2016.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Count occurrences of '-' in each column
dash_counts = (world_happiness_2016 == '-').sum()
dash_counts
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Lower Confidence Interval        0
# Upper Confidence Interval        0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
world_happiness_2016[world_happiness_2016.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Lower Confidence Interval, Upper Confidence Interval, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
world_happiness_2016[world_happiness_2016.duplicated(['Country'])]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Lower Confidence Interval, Upper Confidence Interval, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
world_happiness_2016[world_happiness_2016.duplicated(['Happiness Rank'] , keep=False)]
# Out:
#           Country                           Region  Happiness Rank  \
# 33   Saudi Arabia  Middle East and Northern Africa              34
# 34         Taiwan                     Eastern Asia              34
# 56         Poland       Central and Eastern Europe              57
# 57    South Korea                     Eastern Asia              57
# 144  Burkina Faso               Sub-Saharan Africa             145
# 145        Uganda               Sub-Saharan Africa             145
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 33             6.379                      6.287                      6.471
# 34             6.379                      6.305                      6.453
# 56             5.835                      5.749                      5.921
# 57             5.835                      5.747                      5.923
# 144            3.739                      3.647                      3.831
# ...

# %%
duplicates_count = world_happiness_2016['Happiness Rank'].value_counts()
duplicates_count[duplicates_count > 1]
# Out:
# Happiness Rank
# 57     2
# 34     2
# 145    2
# Name: count, dtype: int64

# %%
expected_ranks = set(range(1, 158))
actual_ranks = set(world_happiness_2016['Happiness Rank'])
missing_ranks = sorted(expected_ranks - actual_ranks)
print("Missing Ranks: ", missing_ranks)
# Out:
# Missing Ranks:  [35, 58, 146]

# %%
world_happiness_2016.loc[world_happiness_2016['Country'] == 'Taiwan', 'Happiness Rank'] = 35
world_happiness_2016.loc[world_happiness_2016['Country'] == 'South Korea', 'Happiness Rank'] = 58
world_happiness_2016.loc[world_happiness_2016['Country'] == 'Uganda', 'Happiness Rank'] = 146

# %%
world_happiness_2016[world_happiness_2016.duplicated(['Happiness Rank'] , keep=False)]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Lower Confidence Interval, Upper Confidence Interval, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %% [markdown]
# # world_happiness_2017 dataset

# %%
world_happiness_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
world_happiness_2017.tail()
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
#      Whisker.low  Economy..GDP.per.Capita.    Family  \
# 150     3.398970                  0.368746  0.945707
# 151     3.260331                  0.777153  0.396103
# 152     3.236570                  0.511136  1.041990
# 153     2.735310                  0.091623  0.629794
# 154     2.521116                  0.000000  0.000000
#
#      Health..Life.Expectancy.   Freedom  Generosity  \
# 150                  0.326425  0.581844    0.252756
# 151                  0.500533  0.081539    0.493664
# ...

# %%
world_happiness_2017.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Count occurrences of '-' in each column
dash_counts = (world_happiness_2017 == '-').sum()
dash_counts
# Out:
# Country                          0
# Happiness.Rank                   0
# Happiness.Score                  0
# Whisker.high                     0
# Whisker.low                      0
# Economy..GDP.per.Capita.         0
# Family                           0
# Health..Life.Expectancy.         0
# Freedom                          0
# Generosity                       0
# Trust..Government.Corruption.    0
# Dystopia.Residual                0
# dtype: int64

# %%
world_happiness_2017[world_happiness_2017.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Country, Happiness.Rank, Happiness.Score, Whisker.high, Whisker.low, Economy..GDP.per.Capita., Family, Health..Life.Expectancy., Freedom, Generosity, Trust..Government.Corruption., Dystopia.Residual]
# Index: []

# %%
world_happiness_2017[world_happiness_2017.duplicated(['Happiness.Rank'] , keep=False)]
# Out:
# Empty DataFrame
# Columns: [Country, Happiness.Rank, Happiness.Score, Whisker.high, Whisker.low, Economy..GDP.per.Capita., Family, Health..Life.Expectancy., Freedom, Generosity, Trust..Government.Corruption., Dystopia.Residual]
# Index: []

# %%
expected_ranks = set(range(1, 155))
actual_ranks = set(world_happiness_2017['Happiness.Rank'])
missing_ranks = sorted(expected_ranks - actual_ranks)
print("Missing Ranks: ", missing_ranks)
# Out:
# Missing Ranks:  []

# %%
duplicates_count = world_happiness_2017['Happiness.Score'].value_counts()
duplicates_count[duplicates_count > 1]
# Out:
# Happiness.Score
# 7.284    2
# 5.838    2
# 6.454    2
# 5.074    2
# Name: count, dtype: int64

# %% [markdown]
# ## thers is no dublicated Happiness rank but there is same Happiness score

# %%
world_happiness_2017[world_happiness_2017.duplicated(['Happiness.Score'] , keep=False)]
# Out:
#         Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 8        Sweden               9            7.284      7.344095     7.223905
# 9     Australia              10            7.284      7.356651     7.211349
# 27      Uruguay              28            6.454      6.545906     6.362094
# 28    Guatemala              29            6.454      6.566874     6.341126
# 54  South Korea              55            5.838      5.922559     5.753441
# 55      Moldova              56            5.838      5.908371     5.767629
# 93      Vietnam              94            5.074      5.147281     5.000719
# 94      Nigeria              95            5.074      5.209500     4.938500
#
#     Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 8                   1.494387  1.478162                  0.830875  0.612924
# 9                   1.484415  1.510042                  0.843887  0.601607
# ...

# %% [markdown]
# # world_happiness_2018 dataset

# %%
world_happiness_2018.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
world_happiness_2018.tail()
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 151           1.073                    0.343                         0.244
# 152           0.991                    0.381                         0.481
# 153           0.608                    0.177                         0.112
# 154           0.000                    0.010                         0.305
# 155           0.627                    0.145                         0.065
#
#      Generosity  Perceptions of corruption
# 151       0.083                      0.064
# ...

# %%
world_happiness_2018.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Count occurrences of '-' in each column
dash_counts = (world_happiness_2018 == '-').sum()
dash_counts
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
world_happiness_2018[world_happiness_2018.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %%
world_happiness_2018[world_happiness_2018.duplicated(['Overall rank'] , keep=False)]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %%
world_happiness_2018[world_happiness_2018.duplicated(['Score'] , keep=False)]
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 72            73           Belarus  5.483           1.039           1.498
# 73            74            Turkey  5.483           1.148           1.380
# 78            79            Greece  5.358           1.154           1.202
# 79            80           Lebanon  5.358           0.965           1.179
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 72                    0.700                         0.307       0.101
# 73                    0.686                         0.324       0.106
# 78                    0.879                         0.131       0.000
# 79                    0.785                         0.503       0.214
#
#     Perceptions of corruption
# 72                      0.154
# 73                      0.109
# 78                      0.044
# 79                      0.136

# %%
expected_ranks = set(range(1, 156))
actual_ranks = set(world_happiness_2018['Overall rank'])
missing_ranks = sorted(expected_ranks - actual_ranks)
print("Missing Ranks", missing_ranks)
# Out:
# Missing Ranks []

# %% [markdown]
# # world_happiness_2019 dataset

# %%
world_happiness_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
world_happiness_2019.tail()
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 151           0.711                    0.614                         0.555
# 152           0.885                    0.499                         0.417
# 153           0.517                    0.361                         0.000
# 154           0.000                    0.105                         0.225
# 155           0.575                    0.295                         0.010
#
#      Generosity  Perceptions of corruption
# 151       0.217                      0.411
# ...

# %%
world_happiness_2019.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Count occurrences of '-' in each column
dash_counts = (world_happiness_2019 == '-').sum()
dash_counts
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
world_happiness_2019[world_happiness_2019.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %%
world_happiness_2019[world_happiness_2019.duplicated(['Overall rank'] , keep=False)]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %%
world_happiness_2019[world_happiness_2019.duplicated(['Score'] , keep=False)]
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 88            89           Morocco  5.208           0.801           0.782
# 89            90        Azerbaijan  5.208           1.043           1.147
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 88                    0.782                         0.418       0.036
# 89                    0.769                         0.351       0.035
#
#     Perceptions of corruption
# 88                      0.076
# 89                      0.182

# %%
expected_ranks = set(range(1, 156))
actual_ranks = set(world_happiness_2019['Overall rank'])
missing_ranks = sorted(expected_ranks - actual_ranks)
print("Missing Ranks", missing_ranks)
# Out:
# Missing Ranks []

# %% [markdown]
# #### 6. Completeness:
# Ensure that no critical data is missing. This might mean checking for null values or required fields that are empty.
#
# We will start by checking the dataset for missing or null values. For this, we can use the isna() method which returns a dataframe of boolean values indicating if a field is null or not. To group all missing values by column, we can include the sum() method.

# %% [markdown]
# # world_happiness_2015 dataset

# %%
world_happiness_2015.isnull().sum().sort_values(ascending = False)
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# # world_happiness_2016 dataset

# %%
world_happiness_2016.isnull().sum().sort_values(ascending = False)
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Lower Confidence Interval        0
# Upper Confidence Interval        0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# # world_happiness_2017 dataset

# %%
world_happiness_2017.isnull().sum().sort_values(ascending = False)
# Out:
# Country                          0
# Happiness.Rank                   0
# Happiness.Score                  0
# Whisker.high                     0
# Whisker.low                      0
# Economy..GDP.per.Capita.         0
# Family                           0
# Health..Life.Expectancy.         0
# Freedom                          0
# Generosity                       0
# Trust..Government.Corruption.    0
# Dystopia.Residual                0
# dtype: int64

# %% [markdown]
# # world_happiness_2018 dataset

# %%
world_happiness_2018.isnull().sum().sort_values(ascending = False)
# Out:
# Perceptions of corruption       1
# Overall rank                    0
# Country or region               0
# GDP per capita                  0
# Score                           0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# dtype: int64

# %%
world_happiness_2018[world_happiness_2018['Perceptions of corruption'].isnull()]
# Out:
#     Overall rank     Country or region  Score  GDP per capita  Social support  \
# 19            20  United Arab Emirates  6.774           2.096           0.776
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 19                     0.67                         0.284       0.186
#
#     Perceptions of corruption
# 19                        NaN

# %%
null_chip_index = world_happiness_2018[world_happiness_2018['Perceptions of corruption'].isnull()].index
null_chip_index
# Out:
# Index([19], dtype='int64')

# %%
world_happiness_2018.loc[null_chip_index, 'Perceptions of corruption'] = '0.000'
# Out:
# C:\Users\attar\AppData\Local\Temp\ipykernel_25056\2903524068.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   world_happiness_2018.loc[null_chip_index, 'Perceptions of corruption'] = '0.000'

# %%
world_happiness_2018.isnull().sum().sort_values(ascending = False)
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %% [markdown]
# # world_happiness_2019 dataset

# %%
world_happiness_2019.isnull().sum().sort_values(ascending = False)
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %% [markdown]
# #### 7. Check Accuracy:
#
# Verify that the data is correct and precise. This could involve comparing data samples with known sources or using validation rules.
#
# **The process includes:**
# 1. Validating the appropriateness of data types for the dataset.
# 2. Identifying outliers  using established validation  rule

# %% [markdown]
# # world_happiness_2015 dataset

# %%
world_happiness_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
world_happiness_2015.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# # world_happiness_2016 dataset

# %%
world_happiness_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
world_happiness_2016.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Lower Confidence Interval        float64
# Upper Confidence Interval        float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# # world_happiness_2017 dataset

# %%
world_happiness_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
world_happiness_2017.dtypes
# Out:
# Country                           object
# Happiness.Rank                     int64
# Happiness.Score                  float64
# Whisker.high                     float64
# Whisker.low                      float64
# Economy..GDP.per.Capita.         float64
# Family                           float64
# Health..Life.Expectancy.         float64
# Freedom                          float64
# Generosity                       float64
# Trust..Government.Corruption.    float64
# Dystopia.Residual                float64
# dtype: object

# %% [markdown]
# # world_happiness_2018 dataset

# %%
world_happiness_2018.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#   Perceptions of corruption
# 0                     0.393
# 1                      0.34
# ...

# %%
world_happiness_2018.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption        object
# dtype: object

# %%
world_happiness_2018['Perceptions of corruption'] = world_happiness_2018['Perceptions of corruption'].map(lambda x : float(x))

# %%
world_happiness_2018.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %% [markdown]
# # world_happiness_2019 dataset

# %%
world_happiness_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
world_happiness_2019.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
# go to clean them

# %%
# check outliers

# %% [markdown]
# **What is an Outlier?**
# Outlier is an row/observation that appears far away and diverges from an overall pattern in a sample.
#
# **What are the types of Outliers?**
# 1. Univariate: These outliers can be found when we look at distribution of a single variable
# 2. Multivariate: are outliers in an n-dimensional space. In order to find them, you have to look at distributions in multi-dimensions. example (hight=100, weight=100) for a person
#
# **What causes Outliers?**
# Whenever we come across outliers, the ideal way to tackle them is to find out the reason of having these outliers. The method to deal with them would then depend on the reason of their occurrence.
#
# Let’s understand various types of outliers:
#
# 1. Data Entry Errors:- Human errors such as errors caused during data collection, recording, or entry can cause outliers in data.
# 2. Measurement Error: It is the most common source of outliers. This is caused when the measurement instrument used turns out to be faulty.
# 3. Data Processing Error: Whenever we perform data mining, we extract data from multiple sources. It is possible that some manipulation or extraction errors may lead to outliers in the dataset.
# 4. Sampling error: For instance, we have to measure the height of athletes. By mistake, we include a few basketball players in the sample. This inclusion is likely to cause outliers in the dataset.
# 5. Natural Outlier: When an outlier is not artificial (due to error), it is a natural outlier. For instance: In my last assignment with one of the renowned insurance company, I noticed that the performance of top 50 financial advisors was far higher than rest of the population. Surprisingly, it was not due to any error. Hence, whenever we perform any data mining activity with advisors, we used to treat this segment separately.
#
#
# **What is the impact of Outliers on a dataset?**
#
#
# ![image.png](https://www.analyticsvidhya.com/wp-content/uploads/2015/02/Outlier_31.png)
#
#
#
# **How to detect Outliers?**
#
# 1. Most commonly used method to detect outliers is visualization (Univariate Graphical Analysis).
#
# We use 3 common visualization methods:
# >- Box-plot: A box plot is a method for graphically depicting groups of numerical data through their quartiles. The box extends from the Q1 to Q3 quartile values of the data, with a line at the median (Q2). The whiskers extend from the edges of the box to show the range of the data. Outlier points are those past the end of the whiskers. Box plots show robust measures of location and spread as well as providing information about symmetry and outliers.
# >
# >
# >![image.png](https://miro.medium.com/v2/resize:fit:698/format:webp/1*VK5iHA2AB28HSZwWwUbNYg.png)
# >
# >
# >- Histogram
# >- Scatter Plot: A scatter plot is a mathematical diagram using Cartesian coordinates to display values for two variables for a set of data. The data are displayed as a collection of points, each having the value of one variable determining the position on the horizontal axis and the value of the other variable determining the position on the vertical axis. The points that are far from the population can be termed as an outlier.
# >
# >
# >![image.png](https://miro.medium.com/v2/resize:fit:4800/format:webp/1*Ov6aH-8yIwNoUxtMFwgx4g.png)
# >
# >
#
# 2. Using statistical method (Univariate Non-Graphical analysis):
# >- Any value, which is beyond the range of -1.5 x IQR to 1.5 x IQR
#
# ![image.png](https://www.whatissixsigma.net/wp-content/uploads/2015/07/Box-Plot-Diagram-to-identify-Outliers-figure-1.png)
#
# >- Use capping methods. Any value which out of range of 5th and 95th percentile can be considered as outlier
# >- Data points, three or more standard deviation away from mean are considered outlier: The Z-score is the signed number of standard deviations by which the value of an observation or data point is above the mean value of what is being observed or measured. While calculating the Z-score we re-scale and center the data and look for data points that are too far from zero. These data points which are way too far from zero will be treated as the outliers. In most of the cases, a threshold of 3 or -3 is used i.e if the Z-score value is greater than or less than 3 or -3 respectively, that data point will be identified as outliers.
# > - Outlier detection is merely a special case of the examination of data for influential data points and it also depends on the business understanding

# %%
# go to univariate graphical analysis
# go to lesson : data visualisation 1 - chart type section
# then go to univariate graphical analysis
# detect outliers using graphs varbaly

# %%
# go to lesson: statistics 1 then statistics 3
# then go to univariate Non graphical analysis
# detect outliers using numerical statistics

# %%
# go to delete ouliers

# %% [markdown]
# ## 2. Data Cleaning:
#
# Preliminary findings from data profiling can lead to cleaning the data by:
# - Handling missing values
# - Correcting errors.
# - Dealing with outliers.
#
# -------------------

# %% [markdown]
# ### Handling missing values:

# %% [markdown]
# **Why my data has missing values?**
# They may occur at two stages:
# 1. Data Extraction: It is possible that there are problems with extraction process. Errors at data extraction stage are typically easy to find and can be corrected easily as well.
# 2. Data collection: These errors occur at time of data collection and are harder to correct.
#
# **Why do we need to handle the missing data?**
# To avoid:
# - Bias the conclusions.
# - Leading the business to make wrong decisions.
#
# **Which are the methods to treat missing values ?**
# 1. Deletion: we delete rows where any of the variable is missing. Simplicity is one of the major advantage of this method, but this method reduces the power of model because it reduces the sample size.
#
# 2. Imputation: is a method to fill in the missing values with estimated ones. This imputation is one of the most frequently used methods.
#
#     2.1. Mean/ Mode/ Median Imputation: It consists of replacing the missing data for a given attribute by the mean or median (quantitative attribute) or mode (qualitative attribute) of all known values of that variable.
#     > It can be of two types:
#     > - Generalized Imputation: In this case, we calculate the mean or median for all non missing values of that variable then replace missing value with mean or median.
#     > - Similar case Imputation: In this case, we calculate average for each group individually of non missing values then replace the missing value based on the group.
#
#     2.2. Constant Value
#
#     2.3. Forward Filling
#
#     2.4. Backward Filling
#
# 6. Prediction Model:  Prediction model is one of the sophisticated method for handling missing data. Here, we create a predictive model to estimate values that will substitute the missing data.  In this case, we divide our data set into two sets: One set with no missing values for the variable and another one with missing values. First data set become training data set of the model while second data set with missing values is test data set and variable with missing values is treated as target variable. Next, we create a model to predict target variable based on other attributes of the training data set and populate missing values of test data set.
#
# > There are 2 drawbacks for this approach:
# > - The model estimated values are usually more well-behaved than the true values
# > - If there are no relationships with attributes in the data set and the attribute with missing values, then the model will not be precise for estimating missing values.
#
# 9. KNN Imputation: In this method of imputation, the missing values of an attribute are imputed using the given number of attributes that are most similar to the attribute whose values are missing. The similarity of two attributes is determined using a distance function. It is also known to have certain advantage & disadvantages.
#
#    > **Advantages:**
#    > - k-nearest neighbour can predict both qualitative & quantitative attributes
#    > - Creation of predictive model for each attribute with missing data is not required
#    > - Attributes with multiple missing values can be easily treated
#    > - Correlation structure of the data is taken into consideration
#
#    > **Disadvantage:**
#    > - KNN algorithm is very time-consuming in analyzing large database. It searches through all the dataset looking for the most similar instances.
#    > - Choice of k-value is very critical. Higher value of k would include attributes which are significantly different from what we need whereas lower value of k implies missing out of significant attributes.
#
# --------------------

# %%
# go back to 6th dimention --> Completeness

# %% [markdown]
# ### Correcting errors
#
# -------------------

# %%
# go back to 7th dimension Accuracy

# %% [markdown]
# ### Dealing with outliers:

# %% [markdown]
# **How to remove Outliers?**
# Most of the ways to deal with outliers are similar to the methods of missing values like deleting rows, transforming them, binning them, treat them as a separate group, imputing values and other statistical methods. Here, we will discuss the common techniques used to deal with outliers:
#
# 1. Deleting rows: We delete outlier values if it is due to data entry error, data processing error or outlier rows are very small in numbers. We can also use trimming at both ends to remove outliers.
#
# 2. Imputing: Like imputation of missing values, we can also impute outliers. We can use mean, median, mode imputation methods. Before imputing values, we should analyse if it is natural outlier or artificial. If it is artificial, we can go with imputing values. We can also use statistical model to predict values of outlier rows and after that we can impute it with predicted values.
#
# 3. Treat separately: If there are significant number of outliers, we should treat them separately in the statistical model. One of the approach is to treat both groups as two different groups and build individual model for both groups and then combine the output.

# %% [markdown]
# ## 3. Univariate Analysis:
#
# This involves examining single variables to understand their characteristics (distribution, central tendency, dispersion, and shape).
#
# We calculate **numerical values** about the data that tells us about the distribution of the data. We also **draw graphs** showing visually how the data is distributed. **To answer the following questions about Features/characteristics of Data:**
# - Where is the center of the data? (location)
# - How much does the data vary? (scale)
# - What is the shape of the data? (shape)
#
# **The benefits of this analysis:**
# Statistics summary gives a high-level idea to identify whether the data has any outliers, data entry error, distribution of data such as the data is normally distributed or left/right skewed
#
# **In this step, we will explore variables one by one using following approaches:**

# %% [markdown]
# ### 1. Univariate Graphical Analysis:
# Method to perform uni-variate analysis will depend on whether the variable type is categorical or numerical.

# %% [markdown]
# # world_happiness_2015 dataset

# %%
world_happiness_2015.head(3)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204

# %%
world_happiness_2015['Region'].unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.histplot(
    world_happiness_2015,
    x='Generosity',
    multiple="stack", # also can be layer or dodge or fill
    alpha=0.8);

# %%
plt.figure(figsize=(15,8))
sns.histplot(
    world_happiness_2015,
    x='Freedom',
    multiple="stack", # also can be layer or dodge or fill
    alpha=0.8);

# %%
counts_Regions = world_happiness_2015['Region'].value_counts()
counts_Regions
# Out:
# Region
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: count, dtype: int64

# %%
counts_Regions.values
# Out:
# array([40, 29, 22, 21, 20,  9,  7,  6,  2,  2])

# %%
plt.figure(figsize=(8, 8))  # Adjust figure size if needed
plt.pie(x=counts_Regions.values,
        labels=counts_Regions.index,
        autopct='%1.0f%%',
        startangle=45,
        shadow=True,
        explode=[0.1] * len(counts_Regions)  # Adjust explosion effect for all slices
       )
plt.title("Frequency of Regions in World Happiness Report (2015)", fontsize=14)
plt.show()

# %%
# Calculate the average happiness rank by region
region_rank_avg = world_happiness_2015.groupby('Region')['Happiness Rank'].mean().sort_values()

# %%
# Plot the average happiness rank by region
plt.figure(figsize=(12, 6))  # Adjust figure size if needed
plt.barh(region_rank_avg.index, region_rank_avg.values, color="skyblue")
plt.xlabel("Average Happiness Rank")
plt.ylabel("Region")
plt.title("Average Happiness Rank by Region (2015)", fontsize=14)
plt.show()

# %%
top_10 = world_happiness_2015.nlargest(10, 'Happiness Score')

# %%
plt.figure(figsize=(12, 6))
plt.barh(top_10['Country'], top_10['Happiness Score']) 
plt.xlabel('Happiness Score') 
plt.ylabel('Country')
plt.title('Top 10 Happiest Countries in 2015')
plt.gca().invert_yaxis()  # Ensures the highest-ranked country is at the top
plt.show()

# %% [markdown]
# # world_happiness_2016 dattaset

# %%
world_happiness_2016.head(1)
# Out:
#    Country          Region  Happiness Rank  Happiness Score  \
# 0  Denmark  Western Europe               1            7.526
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                       7.46                      7.592
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939

# %%
world_happiness_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
#  6   Economy (GDP per Capita)       157 non-null    float64
#  7   Family                         157 non-null    float64
#  8   Health (Life Expectancy)       157 non-null    float64
#  9   Freedom                        157 non-null    float64
#  10  Trust (Government Corruption)  157 non-null    float64
#  11  Generosity                     157 non-null    float64
# ...

# %%
world_happiness_2016['Region'].unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
counts_Regions_16 = world_happiness_2016['Region'].value_counts()
counts_Regions_16
# Out:
# Region
# Sub-Saharan Africa                 38
# Central and Eastern Europe         29
# Latin America and Caribbean        24
# Western Europe                     21
# Middle East and Northern Africa    19
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: count, dtype: int64

# %%
counts_Regions_16.values
# Out:
# array([38, 29, 24, 21, 19,  9,  7,  6,  2,  2])

# %%
plt.figure(figsize=(8, 8))  # Adjust figure size if needed
plt.pie(x=counts_Regions_16.values,
        labels=counts_Regions_16.index,
        autopct='%1.0f%%',
        startangle=45,
        shadow=True,
        explode=[0.1] * len(counts_Regions_16)  # Adjust explosion effect for all slices
       )
plt.title("Frequency of Regions in World Happiness Report (2016)", fontsize=14)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.histplot(
    world_happiness_2016,
    x='Economy (GDP per Capita)',
    multiple="stack", # also can be layer or dodge or fill
    alpha=0.8);

# %%
# Calculate the average happiness rank by region
region_rank_avg_16 = world_happiness_2016.groupby('Region')['Happiness Rank'].mean().sort_values()

# %%
# Plot the average happiness rank by region
plt.figure(figsize=(12, 6))  # Adjust figure size if needed
plt.barh(region_rank_avg_16.index, region_rank_avg_16.values, color="skyblue")
plt.xlabel("Average Happiness Rank")
plt.ylabel("Region")
plt.title("Average Happiness Rank by Region (2016)", fontsize=14)
plt.show()

# %%
top_10 = world_happiness_2016.nlargest(10, 'Happiness Score')

# %%
plt.figure(figsize=(12, 6))
plt.barh(top_10['Country'], top_10['Happiness Score']) 
plt.xlabel('Happiness Score') 
plt.ylabel('Country')
plt.title('Top 10 Happiest Countries in 2016')
plt.gca().invert_yaxis()  # Ensures the highest-ranked country is at the top
plt.show()

# %% [markdown]
# # world_happiness_2017 dataset

# %%
world_happiness_2017.head(1)
# Out:
#   Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0  Norway               1            7.537      7.594445     7.479556
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027

# %%
world_happiness_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness.Rank                 155 non-null    int64
#  2   Happiness.Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy..GDP.per.Capita.       155 non-null    float64
#  6   Family                         155 non-null    float64
#  7   Health..Life.Expectancy.       155 non-null    float64
#  8   Freedom                        155 non-null    float64
#  9   Generosity                     155 non-null    float64
#  10  Trust..Government.Corruption.  155 non-null    float64
#  11  Dystopia.Residual              155 non-null    float64
# ...

# %%
plt.figure(figsize=(10, 6))
plt.plot(world_happiness_2017["Happiness.Rank"], world_happiness_2017["Happiness.Score"], color="red", alpha=0.7)

plt.xlabel("Happiness.Rank")  
plt.ylabel("Happiness.Score")  
plt.title("Line Chart of Happiness.Rank vs. Happiness.Score")

plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(world_happiness_2017["Happiness.Rank"], world_happiness_2017["Economy..GDP.per.Capita."], color="red", alpha=0.7)

plt.xlabel("Happiness.Rank")  
plt.ylabel("Economy..GDP.per.Capita.")  
plt.title("Line Chart of Happiness.Rank vs. Economy..GDP.per.Capita.")

plt.grid()
plt.show()

# %% [markdown]
# # world_happiness_2018 dataset

# %%
world_happiness_2018.head(1)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
#
#    Perceptions of corruption
# 0                      0.393

# %%
plt.figure(figsize=(10, 6))
plt.plot(world_happiness_2018["Overall rank"], world_happiness_2018["Perceptions of corruption"], color="red", alpha=0.7)

plt.xlabel("Overall rank")  
plt.ylabel("Perceptions of corruption")  
plt.title("Line Chart of Overall rank vs. Perceptions of corruption")

plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(world_happiness_2018["Overall rank"], world_happiness_2018["Score"], color="red", alpha=0.7)

plt.xlabel("Overall rank")  
plt.ylabel("Score")  
plt.title("Line Chart of Overall rank vs. Score")

plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.histplot(
    world_happiness_2018,
    x='Freedom to make life choices',
    multiple="stack", # also can be layer or dodge or fill
    alpha=0.8);

# %%
plt.figure(figsize=(15,8))
sns.histplot(
    world_happiness_2018,
    x='Healthy life expectancy',
    multiple="stack", # also can be layer or dodge or fill
    alpha=0.8);

# %% [markdown]
# # world_happiness_2019 dataset

# %%
world_happiness_2019.head(1)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769            1.34           1.587
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
#
#    Perceptions of corruption
# 0                      0.393

# %%
plt.figure(figsize=(10, 6))
plt.plot(world_happiness_2019["Overall rank"], world_happiness_2019["Perceptions of corruption"], color="red", alpha=0.7)

plt.xlabel("Overall rank")  
plt.ylabel("Perceptions of corruption")  
plt.title("Line Chart of Overall rank vs. Perceptions of corruption")

plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(world_happiness_2019["Overall rank"], world_happiness_2019["Score"], color="red", alpha=0.7)

plt.xlabel("Overall rank")  
plt.ylabel("Score")  
plt.title("Line Chart of Overall rank vs. Score")

plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.histplot(
    world_happiness_2019,
    x='Freedom to make life choices',
    multiple="stack", # also can be layer or dodge or fill
    alpha=0.8);

# %%
world_happiness_2019_df = world_happiness_2019[world_happiness_2019['Social support'] > 0]

# %%
plt.figure(figsize=(15,8))
sns.histplot(
    world_happiness_2019_df ,
    x='Social support',
    multiple="stack", # also can be layer or dodge or fill
    alpha=0.8);

# %%
plt.figure(figsize=(15,8))
sns.histplot(
    world_happiness_2019,
    x='Generosity',
    multiple="stack", # also can be layer or dodge or fill
    alpha=0.8);

# %% [markdown]
# #### I. Categorical Variables:
#
# we’ll use frequency table to understand distribution of each category
# - Bar Chart (Ordinal) - Orderd
# - Pie Chart (Nominal) - non Orderd

# %% [markdown]
# #### II. Numerical Variables:
#
# we need to understand the central tendency and spread of the variable (Descriptive Analysis) using:
#    - Box plot
#    - Histogram

# %% [markdown]
# ### 2. Univariate Non-Graphical analysis:
#
# - Where is the center of the data? (location) --> **Measures of central tendency**
# - How much does the data vary? (scale) --> **Measure of variability**
# - What is the shape of the data? (shape) --> **Measures of variation combined with an average (measure of center) gives a good picture of the distribution of the data.**

# %% [markdown]
# # world_happiness_2015 dataset

# %%
world_happiness_2015.describe().T
# Out:
#                                count       mean        std      min  \
# Happiness Rank                 158.0  79.500000  45.754781  1.00000
# Happiness Score                158.0   5.375734   1.145010  2.83900
# Standard Error                 158.0   0.047885   0.017146  0.01848
# Economy (GDP per Capita)       158.0   0.846137   0.403121  0.00000
# Family                         158.0   0.991046   0.272369  0.00000
# Health (Life Expectancy)       158.0   0.630259   0.247078  0.00000
# Freedom                        158.0   0.428615   0.150693  0.00000
# Trust (Government Corruption)  158.0   0.143422   0.120034  0.00000
# Generosity                     158.0   0.237296   0.126685  0.00000
# Dystopia Residual              158.0   2.098977   0.553550  0.32858
#
#                                      25%        50%         75%        max
# Happiness Rank                 40.250000  79.500000  118.750000  158.00000
# ...

# %%
world_happiness_2015.describe(include='object').T
# Out:
#         count unique                 top freq
# Country   158    158         Switzerland    1
# Region    158     10  Sub-Saharan Africa   40

# %% [markdown]
# # world_happiness_2016 dataset

# %%
world_happiness_2016.describe().T
# Out:
#                                count       mean        std      min       25%  \
# Happiness Rank                 157.0  79.000000  45.466105  1.00000  40.00000
# Happiness Score                157.0   5.382185   1.141674  2.90500   4.40400
# Lower Confidence Interval      157.0   5.282395   1.148043  2.73200   4.32700
# Upper Confidence Interval      157.0   5.481975   1.136493  3.07800   4.46500
# Economy (GDP per Capita)       157.0   0.953880   0.412595  0.00000   0.67024
# Family                         157.0   0.793621   0.266706  0.00000   0.64184
# Health (Life Expectancy)       157.0   0.557619   0.229349  0.00000   0.38291
# Freedom                        157.0   0.370994   0.145507  0.00000   0.25748
# Trust (Government Corruption)  157.0   0.137624   0.111038  0.00000   0.06126
# Generosity                     157.0   0.242635   0.133756  0.00000   0.15457
# Dystopia Residual              157.0   2.325807   0.542220  0.81789   2.03171
#
# ...

# %%
world_happiness_2016.describe(include='object').T
# Out:
#         count unique                 top freq
# Country   157    157             Denmark    1
# Region    157     10  Sub-Saharan Africa   38

# %% [markdown]
# # world_happiness_2017 dataset

# %%
world_happiness_2017.describe().T
# Out:
#                                count       mean        std       min  \
# Happiness.Rank                 155.0  78.000000  44.888751  1.000000
# Happiness.Score                155.0   5.354019   1.131230  2.693000
# Whisker.high                   155.0   5.452326   1.118542  2.864884
# Whisker.low                    155.0   5.255713   1.145030  2.521116
# Economy..GDP.per.Capita.       155.0   0.984718   0.420793  0.000000
# Family                         155.0   1.188898   0.287263  0.000000
# Health..Life.Expectancy.       155.0   0.551341   0.237073  0.000000
# Freedom                        155.0   0.408786   0.149997  0.000000
# Generosity                     155.0   0.246883   0.134780  0.000000
# Trust..Government.Corruption.  155.0   0.123120   0.101661  0.000000
# Dystopia.Residual              155.0   1.850238   0.500028  0.377914
#
#                                      25%        50%         75%         max
# ...

# %%
world_happiness_2017.describe(include='object').T
# Out:
#         count unique     top freq
# Country   155    155  Norway    1

# %% [markdown]
# # world_happiness_2018 dataset

# %%
world_happiness_2018.describe().T
# Out:
#                               count       mean        std    min       25%  \
# Overall rank                  156.0  78.500000  45.177428  1.000  39.75000
# Score                         156.0   5.375917   1.119506  2.905   4.45375
# GDP per capita                156.0   0.891449   0.391921  0.000   0.61625
# Social support                156.0   1.213237   0.302372  0.000   1.06675
# Healthy life expectancy       156.0   0.597346   0.247579  0.000   0.42225
# Freedom to make life choices  156.0   0.454506   0.162424  0.000   0.35600
# Generosity                    156.0   0.181006   0.098471  0.000   0.10950
# Perceptions of corruption     156.0   0.111282   0.096597  0.000   0.05075
#
#                                   50%        75%      max
# Overall rank                  78.5000  117.25000  156.000
# Score                          5.3780    6.16850    7.632
# GDP per capita                 0.9495    1.19775    2.096
# Social support                 1.2550    1.46300    1.644
# ...

# %%
world_happiness_2018.describe(include='object').T
# Out:
#                   count unique      top freq
# Country or region   156    156  Finland    1

# %% [markdown]
# # world_happiness_2019 dataset

# %%
world_happiness_2019.describe().T
# Out:
#                               count       mean        std    min       25%  \
# Overall rank                  156.0  78.500000  45.177428  1.000  39.75000
# Score                         156.0   5.407096   1.113120  2.853   4.54450
# GDP per capita                156.0   0.905147   0.398389  0.000   0.60275
# Social support                156.0   1.208814   0.299191  0.000   1.05575
# Healthy life expectancy       156.0   0.725244   0.242124  0.000   0.54775
# Freedom to make life choices  156.0   0.392571   0.143289  0.000   0.30800
# Generosity                    156.0   0.184846   0.095254  0.000   0.10875
# Perceptions of corruption     156.0   0.110603   0.094538  0.000   0.04700
#
#                                   50%        75%      max
# Overall rank                  78.5000  117.25000  156.000
# Score                          5.3795    6.18450    7.769
# GDP per capita                 0.9600    1.23250    1.684
# Social support                 1.2715    1.45250    1.624
# ...

# %%
world_happiness_2019.describe(include='object').T
# Out:
#                   count unique      top freq
# Country or region   156    156  Finland    1

# %%
print("Average Happiness Score in",
      "2015:", world_happiness_2015['Happiness Score'].mean(),
      "2016:", world_happiness_2016['Happiness Score'].mean(),
      "2017:", world_happiness_2017['Happiness.Score'].mean(),
      "2018:", world_happiness_2018['Score'].mean(),
      "2019:", world_happiness_2019['Score'].mean())

print("The average deviation from the mean Happiness Score in",
      "2015:", world_happiness_2015['Happiness Score'].std(),
      "2016:", world_happiness_2016['Happiness Score'].std(),
      "2017:", world_happiness_2017['Happiness.Score'].std(),
      "2018:", world_happiness_2018['Score'].std(),
      "2019:", world_happiness_2019['Score'].std())
# Out:
# Average Happiness Score in 2015: 5.375734177215189 2016: 5.382184713375795 2017: 5.354019355773926 2018: 5.375916666666667 2019: 5.407096153846155
# The average deviation from the mean Happiness Score in 2015: 1.1450101349520665 2016: 1.1416735176005715 2017: 1.1312300899149939 2018: 1.119505852731943 2019: 1.1131198687956712

# %%
np.quantile(world_happiness_2015['Happiness Score'],0.80), np.quantile(world_happiness_2016['Happiness Score'],0.80), np.quantile(world_happiness_2017['Happiness.Score'],0.80), np.quantile(world_happiness_2018['Score'],0.80), np.quantile(world_happiness_2019['Score'],0.80)
# Out:
# (np.float64(6.481800000000001),
#  np.float64(6.4772),
#  np.float64(6.427599811553952),
#  np.float64(6.374),
#  np.float64(6.3))

# %%
np.quantile(world_happiness_2015['Happiness Score'],0.25), np.quantile(world_happiness_2016['Happiness Score'],0.25), np.quantile(world_happiness_2017['Happiness.Score'],0.25), np.quantile(world_happiness_2018['Score'],0.25), np.quantile(world_happiness_2019['Score'],0.25)
# Out:
# (np.float64(4.526),
#  np.float64(4.404),
#  np.float64(4.50550007820129),
#  np.float64(4.45375),
#  np.float64(4.5445))

# %% [markdown]
# ## 4. Bivariate/Multivariate Analysis:
#
# Here, you look at the relationships between two or more variables. This can involve looking for correlations, patterns, and trends that suggest a relationship or an association.
#
# We can perform bi-variate analysis for any combination of categorical and numerical variables. The combination can be:
# | bi-variate variables   | Plot type |
# | ------------- | ------------- |
# | Categorical & Categorical| Stacked Bar Chart |
# | Categorical & numerical  | scatter plot, histogram, box plot|
# | numerical  & numerical  | Scatter plot, line chart|
#
#
# Multivariate Analysis:
# - Heat map
# - Bar Chart
# - Scatter Chart
# - Line Chart

# %% [markdown]
# **Categorical & Categorical --> (Stacked Column Chart)**

# %% [markdown]
# **Categorical & numerical --> (scatter plot, histogram, box plot)**

# %% [markdown]
# **numerical & numerical --> (Scatter plot, line chart)**

# %% [markdown]
# We could also use a correlation matrix to get more specific information about the relationship between these two variables.

# %% [markdown]
# # Q1: What countries or regions rank the highest in overall happiness and each of the six factors contributing to happiness?

# %%
# Function to get the appropriate happiness column for each dataset
def get_happiness_column(df, year):
    if year == 2015 or year == 2016:
        return 'Happiness Rank', 'Happiness Score'
    elif year == 2017:
         return 'Happiness Rank', 'Happiness Score'
    else:  # 2018 and 2019
        return 'Score', 'Score'

# Function to plot top countries in overall happiness for each year in a grid layout
def plot_top_countries_grid(df, year, plot_position):
    happiness_rank_column, happiness_score_column = get_happiness_column(df, year)
    
    # For 2018 and 2019, adjust the column name for "Country" as "Country or region"
    if year == 2018 or year == 2019:
        df = df.rename(columns={'Country or region': 'Country'})
    
    # Sort by Happiness Rank and select top 10 countries
    top_countries = df.sort_values(happiness_rank_column).head(10)
    
    # Create a bar plot for the top 10 countries in the subplot grid
    plt.subplot(2, 3, plot_position)
    sns.barplot(x=happiness_rank_column, y='Country', data=top_countries, palette="Blues_d", hue='Country', legend=False)
    plt.title(f"Top 10 Countries in Overall Happiness - {year}")
    plt.xlabel('Happiness Rank')
    plt.ylabel('Country')
    plt.xticks(rotation=45)

# Set up the figure with 5 subplots (one for each year)
plt.figure(figsize=(16, 12))

# Plot for each year (2015-2019)
plot_top_countries_grid(world_happiness_2015, 2015, 1)
plot_top_countries_grid(world_happiness_2016, 2016, 2)
plot_top_countries_grid(world_happiness_2017, 2017, 3)
plot_top_countries_grid(world_happiness_2018, 2018, 4)
plot_top_countries_grid(world_happiness_2019, 2019, 5)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# # Q2: How did country ranks or scores change between the 2015 and 2016 as well as the 2016 and 2017 reports?

# %%
# Merge the datasets to compare 2015-2016 and 2016-2017 based on 'Country'
merged_2015_2016 = pd.merge(world_happiness_2015[['Country', 'Happiness Rank', 'Happiness Score']],
                             world_happiness_2016[['Country', 'Happiness Rank', 'Happiness Score']],
                             on='Country', suffixes=('_2015', '_2016'))

merged_2016_2017 = pd.merge(world_happiness_2016[['Country', 'Happiness Rank', 'Happiness Score']],
                             world_happiness_2017[['Country', 'Happiness Rank', 'Happiness Score']],
                             on='Country', suffixes=('_2016', '_2017'))

# Plot Rank Changes Over Time for 2015, 2016, 2017
plt.figure(figsize=(14, 8))

for country in merged_2015_2016['Country'].head(10):  # Using top 10 countries for simplicity
    country_data = merged_2015_2016[merged_2015_2016['Country'] == country]
    plt.plot([2015, 2016], [country_data['Happiness Rank_2015'].values[0], country_data['Happiness Rank_2016'].values[0]], marker='o', label=country)

plt.title('Rank Changes for Top 10 Countries (2015-2016)')
plt.xlabel('Year')
plt.ylabel('Happiness Rank')
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.gca().invert_yaxis()  # To have 1 as the top rank
plt.tight_layout()
plt.show()

# Plot Score Changes Over Time for 2015, 2016, 2017
plt.figure(figsize=(14, 8))

for country in merged_2015_2016['Country'].head(10):  # Using top 10 countries for simplicity
    country_data = merged_2015_2016[merged_2015_2016['Country'] == country]
    plt.plot([2015, 2016], [country_data['Happiness Score_2015'].values[0], country_data['Happiness Score_2016'].values[0]], marker='o', label=country)

plt.title('Score Changes for Top 10 Countries (2015-2016)')
plt.xlabel('Year')
plt.ylabel('Happiness Score')
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# Plot Rank Changes Over Time for 2016, 2017
plt.figure(figsize=(14, 8))

for country in merged_2016_2017['Country'].head(10):  # Using top 10 countries for simplicity
    country_data = merged_2016_2017[merged_2016_2017['Country'] == country]
    plt.plot([2016, 2017], [country_data['Happiness Rank_2016'].values[0], country_data['Happiness Rank_2017'].values[0]], marker='o', label=country)

plt.title('Rank Changes for Top 10 Countries (2016-2017)')
plt.xlabel('Year')
plt.ylabel('Happiness Rank')
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.gca().invert_yaxis()  # To have 1 as the top rank
plt.tight_layout()
plt.show()

# Plot Score Changes Over Time for 2016, 2017
plt.figure(figsize=(14, 8))

for country in merged_2016_2017['Country'].head(10):  # Using top 10 countries for simplicity
    country_data = merged_2016_2017[merged_2016_2017['Country'] == country]
    plt.plot([2016, 2017], [country_data['Happiness Score_2016'].values[0], country_data['Happiness Score_2017'].values[0]], marker='o', label=country)

plt.title('Score Changes for Top 10 Countries (2016-2017)')
plt.xlabel('Year')
plt.ylabel('Happiness Score')
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Q3: Did any country experience a significant increase or decrease in happiness?

# %%
# Store in a dictionary
data = {
    2015: world_happiness_2015,
    2016: world_happiness_2016,
    2017: world_happiness_2017,
    2018: world_happiness_2018,
    2019: world_happiness_2019
}

# Standardizing column names to extract happiness scores and country names
column_mapping = {
    2015: {"Country": "Country", "Happiness Score": "Happiness Score"},
    2016: {"Country": "Country", "Happiness Score": "Happiness Score"},
    2017: {"Country": "Country", "Happiness.Score": "Happiness Score"},
    2018: {"Country or region": "Country", "Score": "Happiness Score"},
    2019: {"Country or region": "Country", "Score": "Happiness Score"}
}

for year, df in data.items():
    df.rename(columns=column_mapping[year], inplace=True)
    data[year] = df[["Country", "Happiness Score"]]

# Merging all datasets on the Country column
df_merged = data[2015]
for year in range(2016, 2020):
    df_merged = df_merged.merge(data[year], on="Country", how="outer", suffixes=("", f"_{year}"))

# Print column names for debugging
print("Column Names after merging:", df_merged.columns)

# Ensure correct column names
if "Happiness Score_2019" not in df_merged.columns:
    print("Available columns:", df_merged.columns)

# Compute the change in happiness score from 2015 to 2019
df_merged["Change_2015_2019"] = df_merged["Happiness Score_2019"] - df_merged["Happiness Score"]

# Identify the countries with the most significant increase and decrease
most_increase = df_merged.nlargest(5, "Change_2015_2019")[["Country", "Change_2015_2019"]]
most_decrease = df_merged.nsmallest(5, "Change_2015_2019")[["Country", "Change_2015_2019"]]

# Display the results
print("Countries with the Largest Increase in Happiness Score:")
print(most_increase)

print("\nCountries with the Largest Decrease in Happiness Score:")
print(most_decrease)

# Plotting the changes
plt.figure(figsize=(12, 6))
plt.barh(most_increase["Country"], most_increase["Change_2015_2019"], color='green', label='Increase')
plt.barh(most_decrease["Country"], most_decrease["Change_2015_2019"], color='red', label='Decrease')
plt.xlabel("Happiness Score Change (2015-2019)")
plt.ylabel("Country")
plt.title("Countries with Most Significant Happiness Score Changes (2015-2019)")
plt.legend()
plt.show()
# Out:
# Column Names after merging: Index(['Country', 'Happiness Score', 'Happiness Score_2016',
#        'Happiness Score_2017', 'Happiness Score_2018', 'Happiness Score_2019'],
#       dtype='object')
# Countries with the Largest Increase in Happiness Score:
#           Country  Change_2015_2019
# 14          Benin             1.543
# 69    Ivory Coast             1.289
# 152          Togo             1.246
# 57       Honduras             1.072
# 21   Burkina Faso             1.000
#
# Countries with the Largest Decrease in Happiness Score:
#        Country  Change_2015_2019
# 165  Venezuela            -2.103
# 81     Lesotho            -1.096
# 168     Zambia            -1.022
# 169   Zimbabwe            -0.947
# 56       Haiti            -0.921
