# %%
#Import all relevant libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
 
## This statement allows the visuals to render within your Jupyter Notebook.
# %matplotlib inline

# %% [markdown]
# ## Loading the data
# We can now load the dataset into pandas using the read_csv() function. This converts the CSV file into a Pandas dataframe.

# %%
#Read in the csv file and convert to a Pandas dataframe
World_Happiness_2015= pd.read_csv("2015.csv")
World_Happiness_2016= pd.read_csv("2016.csv")
World_Happiness_2017= pd.read_csv("2017.csv")
World_Happiness_2018= pd.read_csv("2018.csv")
World_Happiness_2019= pd.read_csv("2019.csv")

# %% [markdown]
# ### Viewing the dataframe
# We can get a quick sense of the size of our dataset by using the shape method. This returns a tuple with the number of rows and columns in the dataset.

# %%
World_Happiness_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
World_Happiness_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
World_Happiness_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
World_Happiness_2018.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
World_Happiness_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
#number of rows and columns
World_Happiness_2015.shape, World_Happiness_2016.shape, World_Happiness_2017.shape, World_Happiness_2018.shape, World_Happiness_2019.shape
# Out:
# ((158, 12), (157, 13), (155, 12), (156, 9), (156, 9))

# %% [markdown]
# ## 1. Data Profiling:
# Data profiling is a comprehensive process of examining the data available in an existing dataset and collecting statistics and information about that data.

# %%
# Country – Name of the country.
# Region – Geographic area of the country.
# Happiness Rank – Position based on happiness score.
# Happiness Score – Measured happiness level.
# Standard Error – Error margin in the happiness score.
# Economy (GDP per Capita) – Economic strength per person.
# Family – Strength of social support.
# Health (Life Expectancy) – Average lifespan of people.
# Freedom – Personal freedom in life choices.
# Trust (Government Corruption) – Perceived corruption levels.
# Generosity – Charitable and helping behavior.
# Dystopia Residual – Baseline lowest happiness score.

World_Happiness_2015.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
# Country – Name of the country.
# Region – Geographic area of the country.
# Happiness Rank – Position based on happiness score.
# Happiness Score – Measured happiness level.
# Lower Confidence Interval – Lower bound of happiness score estimate.
# Upper Confidence Interval – Upper bound of happiness score estimate.
# Economy (GDP per Capita) – Economic output per person.
# Family – Strength of social support.
# Health (Life Expectancy) – Average lifespan of people.
# Freedom – Personal freedom in life choices.
# Trust (Government Corruption) – Perceived corruption level.
# Generosity – Willingness to help others.
# Dystopia Residual – Baseline lowest happiness score.
World_Happiness_2016.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
# Country – Name of the country.
# Happiness Rank – Country's position based on happiness score.
# Happiness Score – Measured happiness level.
# Whisker High – Upper confidence bound of the happiness score.
# Whisker Low – Lower confidence bound of the happiness score.
# Economy (GDP per Capita) – Economic strength per person.
# Family – Strength of social support networks.
# Health (Life Expectancy) – Average lifespan of the population.
# Freedom – People's perceived freedom in making life choices.
# Generosity – Willingness to donate/help others.
# Trust (Government Corruption) – Perceived corruption level in government/business.
# Dystopia Residual – Hypothetical lowest happiness benchmark used for comparison.
World_Happiness_2017.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
# Overall Rank – The country's ranking based on happiness score.
# Country or Region – The name of the country or region.
# Score – The happiness score based on survey data.
# GDP per Capita – The economic output per person, indicating wealth.
# Social Support – Strength of personal and social relationships.
# Healthy Life Expectancy – Average expected lifespan in good health.
# Freedom to Make Life Choices – Perceived personal freedom in decision-making.
# Generosity – Willingness of people to donate and help others.
# Perceptions of Corruption – The perceived level of corruption in government and businesses.
World_Happiness_2018.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
# Overall Rank – The country's position in the happiness ranking.
# Country or Region – The name of the country or geographical area.
# Score – The happiness score based on survey responses.
# GDP per Capita – The country's economic strength per person.
# Social Support – Strength of social relationships and support networks.
# Healthy Life Expectancy – Average lifespan adjusted for health quality.
# Freedom to Make Life Choices – People's perceived freedom in life decisions.
# Generosity – Willingness of people to help others and donate.
# Perceptions of Corruption – Public perception of corruption in government and businesses
World_Happiness_2019.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
# The dataset has 158 rows and 12 columns with no missing values.
# It includes object columns ('Country', 'Region'), An integer column ('Happiness Rank'), 9 float columns such as 'Happiness Score', 'Economy', and 'Health'.
# There are 2 columns stored as object type.
# There is 1 integer column ('Happiness Rank'), representing the ranking order.
# The remaining 9 columns are float values, including 'Happiness Score','Economy (GDP per Capita)', 'Health (Life Expectancy)', and others.
# No missing values are present as all columns have 158 non-null entries.
World_Happiness_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
# The dataset has 157 entries and 13 columns.
# 2 object columns: 'Country', 'Region' (both of type object).
# 1 integer column: 'Happiness Rank' (type int64), representing the country's rank based on happiness. 
# 10 float columns: Including 'Happiness Score', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', and 'Dystopia Residual'.
# No missing values: All columns have 157 non-null entries.
World_Happiness_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
#  6   Economy (GDP per Capita)       157 non-null    float64
#  7   Family                         157 non-null    float64
#  8   Health (Life Expectancy)       157 non-null    float64
#  9   Freedom                        157 non-null    float64
#  10  Trust (Government Corruption)  157 non-null    float64
#  11  Generosity                     157 non-null    float64
# ...

# %%
# The dataset has 155 rows and 12 columns with no missing values.
# It includes a object column ('Country'),An integer column ('Happiness.Rank'),10 float columns
World_Happiness_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country                      155 non-null    object
#  1   Happiness Rank               155 non-null    int64
#  2   Happiness Score              155 non-null    float64
#  3   whisker high                 155 non-null    float64
#  4   Whisker low                  155 non-null    float64
#  5   Economy (GDP per Capita)     155 non-null    float64
#  6   Family                       155 non-null    float64
#  7   Health (Life Expectancy)     155 non-null    float64
#  8   Freedom                      155 non-null    float64
#  9   Generosity                   155 non-null    float64
#  10  Trust Government Corruption  155 non-null    float64
#  11  Dystopia Residual            155 non-null    float64
# dtypes: float64(10), int64(1), object(1)
# ...

# %%
# The dataset contains 156 rows and 9 columns, with most columns having no missing values (except for 'Perceptions of corruption' with 155 non-null entries).
# It includes an integer column ('Overall rank'), a categorical column ('Country or region'), and 7 float columns
World_Happiness_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     155 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
# The dataset contains 156 rows and 9 columns with no missing values.
# It includes an integer column ('Overall rank'), a categorical column ('Country or region'), and 7 float columns
World_Happiness_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
World_Happiness_2015.describe(include='object')
# Out:
#             Country              Region
# count           158                 158
# unique          158                  10
# top     Switzerland  Sub-Saharan Africa
# freq              1                  40

# %%
World_Happiness_2016.describe(include='object')
# Out:
#         Country              Region
# count       157                 157
# unique      157                  10
# top     Denmark  Sub-Saharan Africa
# freq          1                  38

# %%
World_Happiness_2017.describe(include='object')
# Out:
#        Country
# count      155
# unique     155
# top     Norway
# freq         1

# %% [markdown]
# The process of profiling differs slightly for categorical and numerical variables due to their inherent differences.
#
# **The two main types of data are:**
# - Quantitative (numerical) data
# - Qualitative (categorical) data

# %% [markdown]
# ### Data Quality Checks
# Data quality checks involve the process of ensuring that the data is accurate, complete, consistent, relevant, and reliable.
#
#
# **Here are typical steps involved in checking data quality:**

# %% [markdown]
# #### 1. Reliability:
# Evaluate the data's source and collection process to determine its trustworthiness.

# %%
# in the kaggle page mentioned data source
#The data from the Gallup World Poll.

# %% [markdown]
# #### 2. Timeliness:
# Ensure the data is up-to-date and reflective of the current situation or the period of interest for the analysis.

# %%
#the data is upp to date from 2015 to 2019

# %% [markdown]
# #### 3. Consistency:
#
# Confirm that the data is consistent within the dataset and across multiple data sources. For example, the same data point should not have different values in different places.

# %%
# check the values that should be the same in all years
# need to compare the data with other data , ensure the same values

# %% [markdown]
# #### 4. Relevance:
# Assess whether the data is appropriate and applicable for the intended analysis. Data that is not relevant can skew results and lead to incorrect conclusions.
#
# **Key considerations for relevance include:**
#
# > 1. Sample Appropriateness: Confirm that your data sample aligns with your analysis objectives. For instance, utilizing data from the Northern region will not yield accurate insights for the Western region of the Kingdom.
# >
# > 2. Variable Selection: Any column will not be relevant for our analysis, we can get rid of these using the drop() method. We will set the “axis” argument to 1 since we’re dealing with columns, and set the “inplace” argument to True to make the change permanent.

# %%
# Drop irrelevant columns

# %%
World_Happiness_2015.head(2)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201

# %%
World_Happiness_2016.head(2)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# 1                        0.41203     0.28083            2.69463

# %%
World_Happiness_2017.head(2)
# Out:
#    Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0   Norway               1            7.537      7.594445     7.479556
# 1  Denmark               2            7.522      7.581728     7.462272
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707

# %%
World_Happiness_2018.head(2)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340

# %%
World_Happiness_2019.head(2)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410

# %%
World_Happiness_2015.shape ,World_Happiness_2016.shape ,World_Happiness_2017.shape ,World_Happiness_2018.shape ,World_Happiness_2019.shape
# Out:
# ((158, 12), (157, 13), (155, 12), (156, 9), (156, 9))

# %% [markdown]
# #### 5. Uniqueness:
# Check for and remove duplicate records to prevent skewed analysis results.

# %%
World_Happiness_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
World_Happiness_2015.duplicated().sum() # There is no duplication
# Out:
# np.int64(0)

# %%
World_Happiness_2015.duplicated(['Happiness Score']).sum()
# Out:
# np.int64(1)

# %%
World_Happiness_2015.duplicated(['Country']).sum()
# Out:
# np.int64(0)

# %%
#1 duplicated
World_Happiness_2015.duplicated(['Happiness Rank']).sum()
# Out:
# np.int64(1)

# %%
# normal duplication
World_Happiness_2015[World_Happiness_2015.duplicated(["Happiness Rank"],keep=False)]
# Out:
#        Country                           Region  Happiness Rank  \
# 81      Jordan  Middle East and Northern Africa              82
# 82  Montenegro       Central and Eastern Europe              82
#
#     Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 81            5.192         0.04524                   0.90198  1.05392
# 82            5.192         0.05235                   0.97438  0.90557
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 81                   0.69639  0.40661                        0.14293
# 82                   0.72521  0.18260                        0.14296
#
#     Generosity  Dystopia Residual
# 81     0.11053            1.87996
# 82     0.16140            2.10017

# %%
World_Happiness_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
World_Happiness_2016.duplicated(['Country']).sum()
# Out:
# np.int64(0)

# %%
World_Happiness_2016.duplicated().sum()
# Out:
# np.int64(0)

# %%
# 3 duplicated (normail)
World_Happiness_2016.duplicated(['Happiness Rank']).sum()
# Out:
# np.int64(3)

# %%
World_Happiness_2016[World_Happiness_2016.duplicated(['Happiness Rank'], keep=False)]
# Out:
#           Country                           Region  Happiness Rank  \
# 33   Saudi Arabia  Middle East and Northern Africa              34
# 34         Taiwan                     Eastern Asia              34
# 56         Poland       Central and Eastern Europe              57
# 57    South Korea                     Eastern Asia              57
# 144  Burkina Faso               Sub-Saharan Africa             145
# 145        Uganda               Sub-Saharan Africa             145
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 33             6.379                      6.287                      6.471
# 34             6.379                      6.305                      6.453
# 56             5.835                      5.749                      5.921
# 57             5.835                      5.747                      5.923
# 144            3.739                      3.647                      3.831
# ...

# %%
World_Happiness_2016[World_Happiness_2016.duplicated(['Happiness Rank'])].describe(include='object')
# Out:
#        Country        Region
# count        3             3
# unique       3             2
# top     Taiwan  Eastern Asia
# freq         1             2

# %%
World_Happiness_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
World_Happiness_2017.duplicated().sum()
# Out:
# np.int64(0)

# %%
World_Happiness_2017.duplicated(['Country']).sum()
# Out:
# np.int64(0)

# %%
World_Happiness_2018.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
World_Happiness_2018.duplicated().sum()
# Out:
# np.int64(0)

# %%
World_Happiness_2018.duplicated(['Overall rank']).sum()
# Out:
# np.int64(0)

# %%
World_Happiness_2018.duplicated(['Country or region']).sum()
# Out:
# np.int64(0)

# %%
World_Happiness_2018.duplicated(['Score']).sum()
# Out:
# np.int64(2)

# %%
World_Happiness_2018[World_Happiness_2018.duplicated(['Score'], keep=False)]
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 72            73           Belarus  5.483           1.039           1.498
# 73            74            Turkey  5.483           1.148           1.380
# 78            79            Greece  5.358           1.154           1.202
# 79            80           Lebanon  5.358           0.965           1.179
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 72                    0.700                         0.307       0.101
# 73                    0.686                         0.324       0.106
# 78                    0.879                         0.131       0.000
# 79                    0.785                         0.503       0.214
#
#     Perceptions of corruption
# 72                      0.154
# 73                      0.109
# 78                      0.044
# 79                      0.136

# %%
World_Happiness_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
World_Happiness_2019.duplicated().sum()
# Out:
# np.int64(0)

# %%
World_Happiness_2019.duplicated(['Overall rank']).sum()
# Out:
# np.int64(0)

# %%
World_Happiness_2019.duplicated(['Country or region']).sum()
# Out:
# np.int64(0)

# %%
World_Happiness_2019.duplicated(['Score']).sum()
# Out:
# np.int64(1)

# %%
World_Happiness_2019[World_Happiness_2019.duplicated(['Score'], keep=False)]
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 88            89           Morocco  5.208           0.801           0.782
# 89            90        Azerbaijan  5.208           1.043           1.147
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 88                    0.782                         0.418       0.036
# 89                    0.769                         0.351       0.035
#
#     Perceptions of corruption
# 88                      0.076
# 89                      0.182

# %%
# go to delete duplicates columns

# %% [markdown]
# #### 6. Completeness:
# Ensure that no critical data is missing. This might mean checking for null values or required fields that are empty.
#
# We will start by checking the dataset for missing or null values. For this, we can use the isna() method which returns a dataframe of boolean values indicating if a field is null or not. To group all missing values by column, we can include the sum() method.

# %%
#Display number missing values per column
World_Happiness_2015.isnull().sum() # no missing values
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
World_Happiness_2016.isnull().sum() # no missing values
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Lower Confidence Interval        0
# Upper Confidence Interval        0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
World_Happiness_2017.isnull().sum()  # no missing values
# Out:
# Country                          0
# Happiness.Rank                   0
# Happiness.Score                  0
# Whisker.high                     0
# Whisker.low                      0
# Economy..GDP.per.Capita.         0
# Family                           0
# Health..Life.Expectancy.         0
# Freedom                          0
# Generosity                       0
# Trust..Government.Corruption.    0
# Dystopia.Residual                0
# dtype: int64

# %%
World_Happiness_2018.isnull().sum() # no missing values
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       1
# dtype: int64

# %%
World_Happiness_2018[World_Happiness_2018['Perceptions of corruption'].isnull()] # missing values
# Out:
#     Overall rank     Country or region  Score  GDP per capita  Social support  \
# 19            20  United Arab Emirates  6.774           2.096           0.776
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 19                     0.67                         0.284       0.186
#
#     Perceptions of corruption
# 19                        NaN

# %%
World_Happiness_2018['Perceptions of corruption'].replace(np.nan, 0, inplace=True)

# %%
World_Happiness_2018[World_Happiness_2018['Perceptions of corruption'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %%
World_Happiness_2019.isnull().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
# go to clean them

# %% [markdown]
# #### 7. Check Accuracy:
#
# Verify that the data is correct and precise. This could involve comparing data samples with known sources or using validation rules.
#
# **The process includes:**
# 1. Validating the appropriateness of data types for the dataset.
# 2. Identifying outliers  using established validation  rule

# %%
# check columns types 
World_Happiness_2015.dtypes # the data types for the columns in dataset are correctly assigned
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
World_Happiness_2016.dtypes # the data types for the columns in dataset are correctly assigned
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Lower Confidence Interval        float64
# Upper Confidence Interval        float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
World_Happiness_2017.dtypes # the data types for the columns in dataset are correctly assigned
# Out:
# Country                           object
# Happiness.Rank                     int64
# Happiness.Score                  float64
# Whisker.high                     float64
# Whisker.low                      float64
# Economy..GDP.per.Capita.         float64
# Family                           float64
# Health..Life.Expectancy.         float64
# Freedom                          float64
# Generosity                       float64
# Trust..Government.Corruption.    float64
# Dystopia.Residual                float64
# dtype: object

# %%
# renames columns in the dataset to make the column names more consistent with other datasets
World_Happiness_2017.rename(columns={'Happiness.Rank': 'Happiness Rank', 'Happiness.Score':'Happiness Score', 'Whisker.high':'whisker high','Whisker.low':'Whisker low','Economy..GDP.per.Capita.':'Economy (GDP per Capita)','Health..Life.Expectancy.':'Health (Life Expectancy)','Trust..Government.Corruption.':'Trust Government Corruption','Dystopia.Residual':'Dystopia Residual'},inplace=True)

# %%
World_Happiness_2018.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
# renames columns in the dataset to make the column names more consistent with other datasets
World_Happiness_2018.rename(columns={'Overall rank':'Happiness Rank','Country or region':'Country','Score':'Happiness Score','GDP per capita':'Economy (GDP per Capita)','Healthy life expectancy':'Health (Life Expectancy)','Freedom to make life choices':'Freedom'},inplace=True)

# %%
World_Happiness_2019.dtypes # the data types for the columns in dataset are correctly assigned
# Out:
# Happiness Rank                 int64
# Country                       object
# Happiness Score              float64
# Economy (GDP per Capita)     float64
# Social support               float64
# Health (Life Expectancy)     float64
# Freedom                      float64
# Generosity                   float64
# Perceptions of corruption    float64
# dtype: object

# %%
World_Happiness_2019.rename(columns={'Overall rank':'Happiness Rank','Country or region':'Country','Score':'Happiness Score','GDP per capita':'Economy (GDP per Capita)','Healthy life expectancy':'Health (Life Expectancy)','Freedom to make life choices':'Freedom'},inplace=True)

# %%
# go to clean them

# %%
# check outliers

# %% [markdown]
# **What is an Outlier?**
# Outlier is an row/observation that appears far away and diverges from an overall pattern in a sample.
#
# **What are the types of Outliers?**
# 1. Univariate: These outliers can be found when we look at distribution of a single variable
# 2. Multivariate: are outliers in an n-dimensional space. In order to find them, you have to look at distributions in multi-dimensions. example (hight=100, weight=100) for a person
#
# **What causes Outliers?**
# Whenever we come across outliers, the ideal way to tackle them is to find out the reason of having these outliers. The method to deal with them would then depend on the reason of their occurrence.
#
# Let’s understand various types of outliers:
#
# 1. Data Entry Errors:- Human errors such as errors caused during data collection, recording, or entry can cause outliers in data.
# 2. Measurement Error: It is the most common source of outliers. This is caused when the measurement instrument used turns out to be faulty.
# 3. Data Processing Error: Whenever we perform data mining, we extract data from multiple sources. It is possible that some manipulation or extraction errors may lead to outliers in the dataset.
# 4. Sampling error: For instance, we have to measure the height of athletes. By mistake, we include a few basketball players in the sample. This inclusion is likely to cause outliers in the dataset.
# 5. Natural Outlier: When an outlier is not artificial (due to error), it is a natural outlier. For instance: In my last assignment with one of the renowned insurance company, I noticed that the performance of top 50 financial advisors was far higher than rest of the population. Surprisingly, it was not due to any error. Hence, whenever we perform any data mining activity with advisors, we used to treat this segment separately.
#
#
# **What is the impact of Outliers on a dataset?**
#
#
# ![image.png](https://www.analyticsvidhya.com/wp-content/uploads/2015/02/Outlier_31.png)
#
#
#
# **How to detect Outliers?**
#
# 1. Most commonly used method to detect outliers is visualization (Univariate Graphical Analysis).
#
# We use 3 common visualization methods:
# >- Box-plot: A box plot is a method for graphically depicting groups of numerical data through their quartiles. The box extends from the Q1 to Q3 quartile values of the data, with a line at the median (Q2). The whiskers extend from the edges of the box to show the range of the data. Outlier points are those past the end of the whiskers. Box plots show robust measures of location and spread as well as providing information about symmetry and outliers.
# >
# >
# >![image.png](https://miro.medium.com/v2/resize:fit:698/format:webp/1*VK5iHA2AB28HSZwWwUbNYg.png)
# >
# >
# >- Histogram
# >- Scatter Plot: A scatter plot is a mathematical diagram using Cartesian coordinates to display values for two variables for a set of data. The data are displayed as a collection of points, each having the value of one variable determining the position on the horizontal axis and the value of the other variable determining the position on the vertical axis. The points that are far from the population can be termed as an outlier.
# >
# >
# >![image.png](https://miro.medium.com/v2/resize:fit:4800/format:webp/1*Ov6aH-8yIwNoUxtMFwgx4g.png)
# >
# >
#
# 2. Using statistical method (Univariate Non-Graphical analysis):
# >- Any value, which is beyond the range of -1.5 x IQR to 1.5 x IQR
#
# ![image.png](https://www.whatissixsigma.net/wp-content/uploads/2015/07/Box-Plot-Diagram-to-identify-Outliers-figure-1.png)
#
# >- Use capping methods. Any value which out of range of 5th and 95th percentile can be considered as outlier
# >- Data points, three or more standard deviation away from mean are considered outlier: The Z-score is the signed number of standard deviations by which the value of an observation or data point is above the mean value of what is being observed or measured. While calculating the Z-score we re-scale and center the data and look for data points that are too far from zero. These data points which are way too far from zero will be treated as the outliers. In most of the cases, a threshold of 3 or -3 is used i.e if the Z-score value is greater than or less than 3 or -3 respectively, that data point will be identified as outliers.
# > - Outlier detection is merely a special case of the examination of data for influential data points and it also depends on the business understanding

# %%
# go to univariate graphical analysis
# go to lesson : data visualisation 1 - chart type section
# then go to univariate graphical analysis
# detect outliers using graphs varbaly

# %%
# go to lesson: statistics 1 then statistics 3
# then go to univariate Non graphical analysis
# detect outliers using numerical statistics

# %%
# go to delete ouliers

# %% [markdown]
# ## 2. Data Cleaning:
#
# Preliminary findings from data profiling can lead to cleaning the data by:
# - Handling missing values
# - Correcting errors.
# - Dealing with outliers.
#
# -------------------

# %% [markdown]
# ### Handling missing values:

# %% [markdown]
# **Why my data has missing values?**
# They may occur at two stages:
# 1. Data Extraction: It is possible that there are problems with extraction process. Errors at data extraction stage are typically easy to find and can be corrected easily as well.
# 2. Data collection: These errors occur at time of data collection and are harder to correct.
#
# **Why do we need to handle the missing data?**
# To avoid:
# - Bias the conclusions.
# - Leading the business to make wrong decisions.
#
# **Which are the methods to treat missing values ?**
# 1. Deletion: we delete rows where any of the variable is missing. Simplicity is one of the major advantage of this method, but this method reduces the power of model because it reduces the sample size.
#
# 2. Imputation: is a method to fill in the missing values with estimated ones. This imputation is one of the most frequently used methods.
#
#     2.1. Mean/ Mode/ Median Imputation: It consists of replacing the missing data for a given attribute by the mean or median (quantitative attribute) or mode (qualitative attribute) of all known values of that variable.
#     > It can be of two types:
#     > - Generalized Imputation: In this case, we calculate the mean or median for all non missing values of that variable then replace missing value with mean or median.
#     > - Similar case Imputation: In this case, we calculate average for each group individually of non missing values then replace the missing value based on the group.
#
#     2.2. Constant Value
#
#     2.3. Forward Filling
#
#     2.4. Backward Filling
#
# 6. Prediction Model:  Prediction model is one of the sophisticated method for handling missing data. Here, we create a predictive model to estimate values that will substitute the missing data.  In this case, we divide our data set into two sets: One set with no missing values for the variable and another one with missing values. First data set become training data set of the model while second data set with missing values is test data set and variable with missing values is treated as target variable. Next, we create a model to predict target variable based on other attributes of the training data set and populate missing values of test data set.
#
# > There are 2 drawbacks for this approach:
# > - The model estimated values are usually more well-behaved than the true values
# > - If there are no relationships with attributes in the data set and the attribute with missing values, then the model will not be precise for estimating missing values.
#
# 9. KNN Imputation: In this method of imputation, the missing values of an attribute are imputed using the given number of attributes that are most similar to the attribute whose values are missing. The similarity of two attributes is determined using a distance function. It is also known to have certain advantage & disadvantages.
#
#    > **Advantages:**
#    > - k-nearest neighbour can predict both qualitative & quantitative attributes
#    > - Creation of predictive model for each attribute with missing data is not required
#    > - Attributes with multiple missing values can be easily treated
#    > - Correlation structure of the data is taken into consideration
#
#    > **Disadvantage:**
#    > - KNN algorithm is very time-consuming in analyzing large database. It searches through all the dataset looking for the most similar instances.
#    > - Choice of k-value is very critical. Higher value of k would include attributes which are significantly different from what we need whereas lower value of k implies missing out of significant attributes.
#
# --------------------

# %%
# go back to 6th dimention --> Completeness

# %% [markdown]
# ### Correcting errors
#
# -------------------

# %%
# go back to 7th dimension Accuracy

# %% [markdown]
# ### Dealing with outliers:

# %% [markdown]
# **How to remove Outliers?**
# Most of the ways to deal with outliers are similar to the methods of missing values like deleting rows, transforming them, binning them, treat them as a separate group, imputing values and other statistical methods. Here, we will discuss the common techniques used to deal with outliers:
#
# 1. Deleting rows: We delete outlier values if it is due to data entry error, data processing error or outlier rows are very small in numbers. We can also use trimming at both ends to remove outliers.
#
# 2. Imputing: Like imputation of missing values, we can also impute outliers. We can use mean, median, mode imputation methods. Before imputing values, we should analyse if it is natural outlier or artificial. If it is artificial, we can go with imputing values. We can also use statistical model to predict values of outlier rows and after that we can impute it with predicted values.
#
# 3. Treat separately: If there are significant number of outliers, we should treat them separately in the statistical model. One of the approach is to treat both groups as two different groups and build individual model for both groups and then combine the output.

# %% [markdown]
# ## 3. Univariate Analysis:
#
# This involves examining single variables to understand their characteristics (distribution, central tendency, dispersion, and shape).
#
# We calculate **numerical values** about the data that tells us about the distribution of the data. We also **draw graphs** showing visually how the data is distributed. **To answer the following questions about Features/characteristics of Data:**
# - Where is the center of the data? (location)
# - How much does the data vary? (scale)
# - What is the shape of the data? (shape)
#
# **The benefits of this analysis:**
# Statistics summary gives a high-level idea to identify whether the data has any outliers, data entry error, distribution of data such as the data is normally distributed or left/right skewed
#
# **In this step, we will explore variables one by one using following approaches:**

# %% [markdown]
# ### 1. Univariate Graphical Analysis:
# Method to perform uni-variate analysis will depend on whether the variable type is categorical or numerical.

# %% [markdown]
# ## 2015

# %%
World_Happiness_2015.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
# Top 10 happiest countries
top_10_countries = World_Happiness_2015.nlargest(10, "Happiness Score")

plt.figure(figsize=(12, 6))
sns.barplot(
    data=top_10_countries,
    x="Happiness Score",
    y="Country",
    palette="viridis",
    order=top_10_countries["Country"]
)

plt.xlabel("Happiness Score")
plt.ylabel("Country")
plt.title("Top 10 Happiest Countries (2015)")
plt.show()
# Out:
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/1283462022.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# the top 10 happiest and least happy countries
top_10_2015 = World_Happiness_2015.nlargest(10, "Happiness Score")
bottom_10_2015 = World_Happiness_2015.nsmallest(10, "Happiness Score")

plt.figure(figsize=(12, 6))
sns.barplot(data=top_10_2015, x="Happiness Score", y="Country", palette="viridis")
plt.xlabel("Happiness Score")
plt.ylabel("Country")
plt.title("Top 10 Happiest Countries (2015)")
plt.show()

plt.figure(figsize=(12, 6))
sns.barplot(data=bottom_10_2015, x="Happiness Score", y="Country", palette="magma")
plt.xlabel("Happiness Score")
plt.ylabel("Country")
plt.title("Bottom 10 Least Happy Countries (2015)")
plt.show()
# Out:
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/129894490.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_10_2015, x="Happiness Score", y="Country", palette="viridis")
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/129894490.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=bottom_10_2015, x="Happiness Score", y="Country", palette="magma")

# %% [markdown]
# ## 2016

# %%
World_Happiness_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
# Top 10 happiest countries
top_10_countries = World_Happiness_2016.nlargest(10, "Happiness Score")


plt.figure(figsize=(12, 6))
sns.barplot(
    data=top_10_countries,
    x="Happiness Score",
    y="Country",
    palette="viridis",
    order=top_10_countries["Country"]
)

plt.xlabel("Happiness Score")
plt.ylabel("Country")
plt.title("Top 10 Happiest Countries (2016)")
plt.show()
# Out:
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/3979341146.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# Get the top 10 happiest and least happy countries
top_10_2016 = World_Happiness_2016.nlargest(10, "Happiness Score")
bottom_10_2016 = World_Happiness_2016.nsmallest(10, "Happiness Score")


plt.figure(figsize=(12, 6))
sns.barplot(data=top_10_2016, x="Happiness Score", y="Country", palette="viridis")
plt.xlabel("Happiness Score")
plt.ylabel("Country")
plt.title("Top 10 Happiest Countries (2016)")
plt.show()

plt.figure(figsize=(12, 6))
sns.barplot(data=bottom_10_2016, x="Happiness Score", y="Country", palette="magma")
plt.xlabel("Happiness Score")
plt.ylabel("Country")
plt.title("Bottom 10 Least Happy Countries (2016)")
plt.show()
# Out:
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/3125606849.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_10_2016, x="Happiness Score", y="Country", palette="viridis")
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/3125606849.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=bottom_10_2016, x="Happiness Score", y="Country", palette="magma")

# %% [markdown]
# ## 2017

# %%
World_Happiness_2017.head()
# Out:
#        Country  Happiness Rank  Happiness Score  whisker high  Whisker low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust Government Corruption  Dystopia Residual
# ...

# %%
World_Happiness_2017.tail()
# Out:
#                       Country  Happiness Rank  Happiness Score  whisker high  \
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
#      Whisker low  Economy (GDP per Capita)    Family  \
# 150     3.398970                  0.368746  0.945707
# 151     3.260331                  0.777153  0.396103
# 152     3.236570                  0.511136  1.041990
# 153     2.735310                  0.091623  0.629794
# 154     2.521116                  0.000000  0.000000
#
#      Health (Life Expectancy)   Freedom  Generosity  \
# 150                  0.326425  0.581844    0.252756
# 151                  0.500533  0.081539    0.493664
# ...

# %%
# Top 10 happiest countries
top_10_countries = World_Happiness_2017.nlargest(10, "Happiness Score")


plt.figure(figsize=(12, 6))
sns.barplot(
    data=top_10_countries,
    x="Happiness Score",
    y="Country",
    palette="viridis",
    order=top_10_countries["Country"]
)

plt.xlabel("Happiness Score")
plt.ylabel("Country")
plt.title("Top 10 Happiest Countries (2017)")
plt.show()
# Out:
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/4164866380.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# Get the top 10 happiest and least happy countries
top_10_2017 = World_Happiness_2017.nlargest(10, "Happiness Score")
bottom_10_2017 = World_Happiness_2017.nsmallest(10, "Happiness Score")


plt.figure(figsize=(12, 6))
sns.barplot(data=top_10_2017, x="Happiness Score", y="Country", palette="viridis")
plt.xlabel("Happiness Score")
plt.ylabel("Country")
plt.title("Top 10 Happiest Countries (2017)")
plt.show()

plt.figure(figsize=(12, 6))
sns.barplot(data=bottom_10_2017, x="Happiness Score", y="Country", palette="magma")
plt.xlabel("Happiness Score")
plt.ylabel("Country")
plt.title("Bottom 10 Least Happy Countries (2017)")
plt.show()
# Out:
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/3985083740.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_10_2017, x="Happiness Score", y="Country", palette="viridis")
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/3985083740.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=bottom_10_2017, x="Happiness Score", y="Country", palette="magma")

# %% [markdown]
# ## 2018

# %%
World_Happiness_2018.head()
# Out:
#    Happiness Rank      Country  Happiness Score  Economy (GDP per Capita)  \
# 0               1      Finland            7.632                     1.305
# 1               2       Norway            7.594                     1.456
# 2               3      Denmark            7.555                     1.351
# 3               4      Iceland            7.495                     1.343
# 4               5  Switzerland            7.487                     1.420
#
#    Social support  Health (Life Expectancy)  Freedom  Generosity  \
# 0           1.592                     0.874    0.681       0.202
# 1           1.582                     0.861    0.686       0.286
# 2           1.590                     0.868    0.683       0.284
# 3           1.644                     0.914    0.677       0.353
# 4           1.549                     0.927    0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# 2                      0.408
# ...

# %%
top_10_countries = World_Happiness_2018.nlargest(10, "Happiness Score")

# Plot top 10 happiest countries
plt.figure(figsize=(12, 6))
sns.barplot(
    data=top_10_countries,
    x="Happiness Score",
    y="Country",
    palette="viridis",
    order=top_10_countries["Country"]
)

plt.xlabel("Happiness Score")
plt.ylabel("Country")
plt.title("Top 10 Happiest Countries (2018)")
plt.show()
# Out:
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/843996302.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
top_10_2018 = World_Happiness_2018.nlargest(10, "Happiness Score")
bottom_10_2018 = World_Happiness_2018.nsmallest(10, "Happiness Score")


plt.figure(figsize=(12, 6))
sns.barplot(data=top_10_2018, x="Happiness Score", y="Country", palette="viridis")
plt.xlabel("Happiness Score")
plt.ylabel("Country")
plt.title("Top 10 Happiest Countries (2018)")
plt.show()

plt.figure(figsize=(12, 6))
sns.barplot(data=bottom_10_2018, x="Happiness Score", y="Country", palette="magma")
plt.xlabel("Happiness Score")
plt.ylabel("Country")
plt.title("Bottom 10 Least Happy Countries (2018)")
plt.show()
# Out:
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/2926818216.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_10_2018, x="Happiness Score", y="Country", palette="viridis")
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/2926818216.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=bottom_10_2018, x="Happiness Score", y="Country", palette="magma")

# %% [markdown]
# ## 2019

# %%
World_Happiness_2019.head()
# Out:
#    Happiness Rank      Country  Happiness Score  Economy (GDP per Capita)  \
# 0               1      Finland            7.769                     1.340
# 1               2      Denmark            7.600                     1.383
# 2               3       Norway            7.554                     1.488
# 3               4      Iceland            7.494                     1.380
# 4               5  Netherlands            7.488                     1.396
#
#    Social support  Health (Life Expectancy)  Freedom  Generosity  \
# 0           1.587                     0.986    0.596       0.153
# 1           1.573                     0.996    0.592       0.252
# 2           1.582                     1.028    0.603       0.271
# 3           1.624                     1.026    0.591       0.354
# 4           1.522                     0.999    0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# ...

# %%
top_10_countries = World_Happiness_2019.nlargest(10, "Happiness Score")

# Plot top 10 happiest countries
plt.figure(figsize=(12, 6))
sns.barplot(
    data=top_10_countries,
    x="Happiness Score",
    y="Country",
    palette="viridis",
    order=top_10_countries["Country"]
)

plt.xlabel("Happiness Score")
plt.ylabel("Country")
plt.title("Top 10 Happiest Countries (2019)")
plt.show()
# Out:
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/474193971.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
top_10_2019 = World_Happiness_2018.nlargest(10, "Happiness Score")
bottom_10_2019 = World_Happiness_2018.nsmallest(10, "Happiness Score")

# Plot
plt.figure(figsize=(12, 6))
sns.barplot(data=top_10_2019, x="Happiness Score", y="Country", palette="viridis")
plt.xlabel("Happiness Score")
plt.ylabel("Country")
plt.title("Top 10 Happiest Countries (2019)")
plt.show()

plt.figure(figsize=(12, 6))
sns.barplot(data=bottom_10_2019, x="Happiness Score", y="Country", palette="magma")
plt.xlabel("Happiness Score")
plt.ylabel("Country")
plt.title("Bottom 10 Least Happy Countries (2019)")
plt.show()
# Out:
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/2012071565.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_10_2019, x="Happiness Score", y="Country", palette="viridis")
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/2012071565.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=bottom_10_2019, x="Happiness Score", y="Country", palette="magma")

# %% [markdown]
# ## What countries or regions rank the highest in overall happiness and each of the six factors contributing to happiness?

# %%
#World_Happiness_2015

# Factors contributing to happiness
factors = ['Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 
           'Freedom', 'Trust (Government Corruption)', 'Generosity']
plt.figure(figsize=(14, 10))

for i, factor in enumerate(factors, 1):
    plt.subplot(2, 3, i)
    top_countries = World_Happiness_2015.nlargest(10, factor)
    sns.barplot(x='Happiness Score', y='Country', data=top_countries, palette='viridis')
    plt.title(f'Top 10 Countries by {factor}')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/1331893851.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Happiness Score', y='Country', data=top_countries, palette='viridis')
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/1331893851.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Happiness Score', y='Country', data=top_countries, palette='viridis')
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/1331893851.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
# World_Happiness_2016

# Top 10 Countries by Economy (GDP per Capita) (2016) – Countries with strong economies, such as Norway and Switzerland, continue to rank higher in overall happiness.

# Factors contributing to happiness
factors = ['Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 
           'Freedom', 'Trust (Government Corruption)', 'Generosity']
plt.figure(figsize=(14, 10))

for i, factor in enumerate(factors, 1):
    plt.subplot(2, 3, i)
    top_countries = World_Happiness_2016.nlargest(10, factor)
    sns.barplot(x='Happiness Score', y='Country', data=top_countries, palette='viridis')
    plt.title(f'Top 10 Countries by {factor}')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/1622356055.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Happiness Score', y='Country', data=top_countries, palette='viridis')
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/1622356055.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Happiness Score', y='Country', data=top_countries, palette='viridis')
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/1622356055.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
World_Happiness_2017.head()
# Out:
#        Country  Happiness Rank  Happiness Score  whisker high  Whisker low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust Government Corruption  Dystopia Residual
# ...

# %%
#World_Happiness_2017

factors = ['Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 
           'Freedom', 'Trust Government Corruption', 'Generosity']
plt.figure(figsize=(14, 10))

for i, factor in enumerate(factors, 1):
    plt.subplot(2, 3, i)
    top_countries = World_Happiness_2017.nlargest(10, factor)
    sns.barplot(x='Happiness Score', y='Country', data=top_countries, palette='viridis')
    plt.title(f'Top 10 Countries by {factor}')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/2648115976.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Happiness Score', y='Country', data=top_countries, palette='viridis')
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/2648115976.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Happiness Score', y='Country', data=top_countries, palette='viridis')
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/2648115976.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
World_Happiness_2018.head()
# Out:
#    Happiness Rank      Country  Happiness Score  Economy (GDP per Capita)  \
# 0               1      Finland            7.632                     1.305
# 1               2       Norway            7.594                     1.456
# 2               3      Denmark            7.555                     1.351
# 3               4      Iceland            7.495                     1.343
# 4               5  Switzerland            7.487                     1.420
#
#    Social support  Health (Life Expectancy)  Freedom  Generosity  \
# 0           1.592                     0.874    0.681       0.202
# 1           1.582                     0.861    0.686       0.286
# 2           1.590                     0.868    0.683       0.284
# 3           1.644                     0.914    0.677       0.353
# 4           1.549                     0.927    0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# 2                      0.408
# ...

# %%
#World_Happiness_2018


# Factors contributing to happiness
factors = ['Economy (GDP per Capita)', 'Health (Life Expectancy)', 
           'Freedom', 'Generosity','Perceptions of corruption','Social support']
plt.figure(figsize=(14, 10))

for i, factor in enumerate(factors, 1):
    plt.subplot(2, 3, i)
    top_countries = World_Happiness_2018.nlargest(10, factor)
    sns.barplot(x='Happiness Score', y='Country', data=top_countries, palette='viridis')
    plt.title(f'Top 10 Countries by {factor}')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/1025406035.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Happiness Score', y='Country', data=top_countries, palette='viridis')
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/1025406035.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Happiness Score', y='Country', data=top_countries, palette='viridis')
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/1025406035.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
World_Happiness_2019.head()
# Out:
#    Happiness Rank      Country  Happiness Score  Economy (GDP per Capita)  \
# 0               1      Finland            7.769                     1.340
# 1               2      Denmark            7.600                     1.383
# 2               3       Norway            7.554                     1.488
# 3               4      Iceland            7.494                     1.380
# 4               5  Netherlands            7.488                     1.396
#
#    Social support  Health (Life Expectancy)  Freedom  Generosity  \
# 0           1.587                     0.986    0.596       0.153
# 1           1.573                     0.996    0.592       0.252
# 2           1.582                     1.028    0.603       0.271
# 3           1.624                     1.026    0.591       0.354
# 4           1.522                     0.999    0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# ...

# %%
#World_Happiness_2019


# Factors contributing to happiness
factors = ['Economy (GDP per Capita)', 'Social support', 'Health (Life Expectancy)', 
           'Freedom', 'Perceptions of corruption', 'Generosity']
plt.figure(figsize=(14, 10))

for i, factor in enumerate(factors, 1):
    plt.subplot(2, 3, i)
    top_countries = World_Happiness_2019.nlargest(10, factor)
    sns.barplot(x='Happiness Score', y='Country', data=top_countries, palette='viridis')
    plt.title(f'Top 10 Countries by {factor}')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/4158893696.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Happiness Score', y='Country', data=top_countries, palette='viridis')
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/4158893696.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Happiness Score', y='Country', data=top_countries, palette='viridis')
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/4158893696.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# ## How did country ranks or scores change between the 2015 and 2016 as well as the 2016 and 2017 reports?

# %%
# Merge datasets for 2015-2016
df_comparison_2015_2016 = pd.merge(
    World_Happiness_2015[['Country', 'Happiness Score']],
    World_Happiness_2016[['Country', 'Happiness Score']],
    on='Country',
    suffixes=('_2015', '_2016')
).head(15)

# Merge datasets for 2016-2017
df_comparison_2016_2017 = pd.merge(
    World_Happiness_2016[['Country', 'Happiness Score']],
    World_Happiness_2017[['Country', 'Happiness Score']],
    on='Country',
    suffixes=('_2016', '_2017')
).head(15)


fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Plot Happiness Scores for 2015-2016
sns.barplot(x='Happiness Score_2015', y='Country', data=df_comparison_2015_2016, ax=axes[0], color='blue')
axes[0].set_title('Happiness Scores 2015 vs 2016')
axes[0].set_xlabel('Happiness Score')
axes[0].set_ylabel('Country')

# Plot Happiness Scores for 2016-2017
sns.barplot(x='Happiness Score_2016', y='Country', data=df_comparison_2016_2017, ax=axes[1], color='green')
axes[1].set_title('Happiness Scores 2016 vs 2017')
axes[1].set_xlabel('Happiness Score')
axes[1].set_ylabel('Country')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Did any country experience a significant increase or decrease in happiness?

# %%
# Calculate the change in Happiness Score between 2015-2016 and 2016-2017

# shows the top 10 countries that had the largest increases in their happiness scores, positive change.
# The second plot shows the top 10 countries with the largest decreases in happiness, negative change.
world_happiness_reports_2015_2016 = pd.merge(
    World_Happiness_2015[['Country', 'Happiness Score']],
    World_Happiness_2016[['Country', 'Happiness Score']],
    on='Country', suffixes=('_2015', '_2016')
)

world_happiness_reports_2015_2016['Change_2015_2016'] = (
    world_happiness_reports_2015_2016['Happiness Score_2016'] - 
    world_happiness_reports_2015_2016['Happiness Score_2015']
)

# Select the biggest increases and decreases
top_increases = world_happiness_reports_2015_2016.nlargest(10, 'Change_2015_2016')
top_decreases = world_happiness_reports_2015_2016.nsmallest(10, 'Change_2015_2016')

# Plotting the results
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.barplot(x='Change_2015_2016', y='Country', data=top_increases, ax=axes[0], palette='Greens')
axes[0].set_title('Top 10 Countries with Increased Happiness (2015-2016)')
axes[0].set_xlabel('Happiness Score Change')

sns.barplot(x='Change_2015_2016', y='Country', data=top_decreases, ax=axes[1], palette='Reds')
axes[1].set_title('Top 10 Countries with Decreased Happiness (2015-2016)')
axes[1].set_xlabel('Happiness Score Change')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/349065596.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Change_2015_2016', y='Country', data=top_increases, ax=axes[0], palette='Greens')
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/349065596.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Change_2015_2016', y='Country', data=top_decreases, ax=axes[1], palette='Reds')

# %% [markdown]
# ## (Bonus Analysis) How do the top 10 happiest countries in 2015 compare to the top 10 happiest countries in 2016?

# %%
#for exapmle in 2015, Switzerland had a happiness score of 7.5 and In 2016, Switzerland's happiness score increased to 7.6. This indicates a small but positive change in the country's overall happiness from 2015 to 2016, which might be due to improvements in various factors like economy, social support, or freedom

# Select top 10 happiest countries in 2015 and 2016
top_10_happiness_2015 = World_Happiness_2015.nlargest(10, 'Happiness Score')
top_10_happiness_2016 = World_Happiness_2016.nlargest(10, 'Happiness Score')

# Merge both datasets on the 'Country' column
top_10_comparison = pd.merge(
    top_10_happiness_2015[['Country', 'Happiness Score']],
    top_10_happiness_2016[['Country', 'Happiness Score']],
    on='Country', suffixes=('_2015', '_2016')
)


fig, axes = plt.subplots(1, 2, figsize=(16, 6))


sns.barplot(x='Happiness Score_2015', y='Country', data=top_10_comparison, ax=axes[0], palette='Blues_r')
axes[0].set_title('Top 10 Happiest Countries (2015)')
axes[0].set_xlabel('Happiness Score')


sns.barplot(x='Happiness Score_2016', y='Country', data=top_10_comparison, ax=axes[1], palette='Greens_r')
axes[1].set_title('Top 10 Happiest Countries (2016)')
axes[1].set_xlabel('Happiness Score')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/4120108167.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Happiness Score_2015', y='Country', data=top_10_comparison, ax=axes[0], palette='Blues_r')
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_98784/4120108167.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Happiness Score_2016', y='Country', data=top_10_comparison, ax=axes[1], palette='Greens_r')

# %% [markdown]
# #### I. Categorical Variables:
#
# we’ll use frequency table to understand distribution of each category
# - Bar Chart (Ordinal) - Orderd
# - Pie Chart (Nominal) - non Orderd

# %% [markdown]
# #### II. Numerical Variables:
#
# we need to understand the central tendency and spread of the variable (Descriptive Analysis) using:
#    - Box plot
#    - Histogram

# %% [markdown]
# ### 2. Univariate Non-Graphical analysis:
#
# - Where is the center of the data? (location) --> **Measures of central tendency**
# - How much does the data vary? (scale) --> **Measure of variability**
# - What is the shape of the data? (shape) --> **Measures of variation combined with an average (measure of center) gives a good picture of the distribution of the data.**

# %% [markdown]
# ## 4. Bivariate/Multivariate Analysis:
#
# Here, you look at the relationships between two or more variables. This can involve looking for correlations, patterns, and trends that suggest a relationship or an association.
#
# We can perform bi-variate analysis for any combination of categorical and numerical variables. The combination can be:
# | bi-variate variables   | Plot type |
# | ------------- | ------------- |
# | Categorical & Categorical| Stacked Bar Chart |
# | Categorical & numerical  | scatter plot, histogram, box plot|
# | numerical  & numerical  | Scatter plot, line chart|
#
#
# Multivariate Analysis:
# - Heat map
# - Bar Chart
# - Scatter Chart
# - Line Chart

# %% [markdown]
# **Categorical & Categorical --> (Stacked Column Chart)**

# %% [markdown]
# **Categorical & numerical --> (scatter plot, histogram, box plot)**

# %% [markdown]
# **numerical & numerical --> (Scatter plot, line chart)**

# %% [markdown]
# We could also use a correlation matrix to get more specific information about the relationship between these two variables.
