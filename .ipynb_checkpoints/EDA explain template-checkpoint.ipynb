# %%
#Import all relevant libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
 
## This statement allows the visuals to render within your Jupyter Notebook.
# %matplotlib inline

# %% [markdown]
# ## Loading the data
# We can now load the dataset into pandas using the read_csv() function. This converts the CSV file into a Pandas dataframe.

# %%
#Read in the csv file and convert to a Pandas dataframe
world_hap2015 = pd.read_csv("Data/2015.csv")
world_hap2016 = pd.read_csv("Data/2016.csv")
world_hap2017 = pd.read_csv("Data/2017.csv")
world_hap2018 = pd.read_csv("Data/2018.csv")
world_hap2019 = pd.read_csv("Data/2019.csv")

# %% [markdown]
# ### Viewing the dataframe
# We can get a quick sense of the size of our dataset by using the shape method. This returns a tuple with the number of rows and columns in the dataset.

# %%
world_hap2015.head(4)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531

# %%
world_hap2016.head(4)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
# 3                   1.57744  1.12690                   0.79579  0.59609
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# 1                        0.41203     0.28083            2.69463
# 2                        0.14975     0.47678            2.83137
# 3                        0.35776     0.37895            2.66465

# %%
world_hap2017.head(4)
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707
# 2    0.475540                       0.153527           2.322715
# 3    0.290549                       0.367007           2.276716

# %%
world_hap2018.head(4)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# 2                      0.408
# 3                      0.138

# %%
world_hap2019.head(4)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118

# %%
world_hap2015.shape, world_hap2016.shape, world_hap2017.shape, world_hap2018.shape, world_hap2019.shape
# Out:
# ((158, 12), (157, 13), (155, 12), (156, 9), (156, 9))

# %% [markdown]
# ## 1. Data Profiling:
# Data profiling is a comprehensive process of examining the data available in an existing dataset and collecting statistics and information about that data.

# %%
world_hap2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %%
world_hap2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
#  6   Economy (GDP per Capita)       157 non-null    float64
#  7   Family                         157 non-null    float64
#  8   Health (Life Expectancy)       157 non-null    float64
#  9   Freedom                        157 non-null    float64
#  10  Trust (Government Corruption)  157 non-null    float64
#  11  Generosity                     157 non-null    float64
#  12  Dystopia Residual              157 non-null    float64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 16.1+ KB

# %%
world_hap2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness.Rank                 155 non-null    int64
#  2   Happiness.Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy..GDP.per.Capita.       155 non-null    float64
#  6   Family                         155 non-null    float64
#  7   Health..Life.Expectancy.       155 non-null    float64
#  8   Freedom                        155 non-null    float64
#  9   Generosity                     155 non-null    float64
#  10  Trust..Government.Corruption.  155 non-null    float64
#  11  Dystopia.Residual              155 non-null    float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 14.7+ KB

# %%
world_hap2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     155 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
world_hap2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
world_hap2015.describe(include='object')
# Out:
#             Country              Region
# count           158                 158
# unique          158                  10
# top     Switzerland  Sub-Saharan Africa
# freq              1                  40

# %%
world_hap2016.describe(include='object')
# Out:
#         Country              Region
# count       157                 157
# unique      157                  10
# top     Denmark  Sub-Saharan Africa
# freq          1                  38

# %%
world_hap2017.describe(include='object')
# Out:
#        Country
# count      155
# unique     155
# top     Norway
# freq         1

# %%
world_hap2018.describe(include='object')
# Out:
#        Country or region
# count                156
# unique               156
# top              Finland
# freq                   1

# %%
world_hap2019.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# 25%                   0.547750                      0.308000    0.108750
# 50%                   0.789000                      0.417000    0.177500
# 75%                   0.881750                      0.507250    0.248250
# max                   1.141000                      0.631000    0.566000
#
#        Perceptions of corruption
# count                 156.000000
# mean                    0.110603
# std                     0.094538
# min                     0.000000
# 25%                     0.047000
# 50%                     0.085500
# 75%                     0.141250
# max                     0.453000

# %% [markdown]
# The process of profiling differs slightly for categorical and numerical variables due to their inherent differences.
#
# **The two main types of data are:**
# - Quantitative (numerical) data
# - Qualitative (categorical) data

# %% [markdown]
# ### Data Quality Checks
# Data quality checks involve the process of ensuring that the data is accurate, complete, consistent, relevant, and reliable.
#
#
# **Here are typical steps involved in checking data quality:**

# %% [markdown]
# #### 1. Reliability:
# Evaluate the data's source and collection process to determine its trustworthiness.

# %%
# The Data is from kaggle and it's public data and what mentaion that the data was taken from "Gallup World Poll".
# Gallup World Poll is survey globally to measure people's well-being, social support, and economic perceptions.

# %% [markdown]
# #### 2. Timeliness:
# Ensure the data is up-to-date and reflective of the current situation or the period of interest for the analysis.

# %%
# Data exists for the period specified in the Problem Statement, from 2015 to four years after (2015–2019).
# it's not up to date.

# %% [markdown]
# #### 3. Consistency:
#
# Confirm that the data is consistent within the dataset and across multiple data sources. For example, the same data point should not have different values in different places.

# %%
# As per that the data is public and globliy, it’s helpful to verify it with similar organizations or sources.

# %% [markdown]
# #### 4. Relevance:
# Assess whether the data is appropriate and applicable for the intended analysis. Data that is not relevant can skew results and lead to incorrect conclusions.
#
# **Key considerations for relevance include:**
#
# > 1. Sample Appropriateness: Confirm that your data sample aligns with your analysis objectives. For instance, utilizing data from the Northern region will not yield accurate insights for the Western region of the Kingdom.
# >
# > 2. Variable Selection: Any column will not be relevant for our analysis, we can get rid of these using the drop() method. We will set the “axis” argument to 1 since we’re dealing with columns, and set the “inplace” argument to True to make the change permanent.

# %%
# Based on the problem statemnt the dataset is related to objctive problem which is lay on this between 2015-2019
# in 2015 vs 2016 in compere the change in ranks all columns is related
# 'Standard Error' in dataset 2015 and Lower Confidence Interval, and Upper Confidence Interval are relate in uncertainty in the Happiness Score
# As for 2017 same columns and for this columns: Whisker.high and Whisker.low has same concept of Lower Confidence Interval, and Upper Confidence Interval
# So we will process furthe without drop any columns for those datasets

# %% [markdown]
# #### 5. Uniqueness:
# Check for and remove duplicate records to prevent skewed analysis results.

# %%
world_hap2015[world_hap2015.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Standard Error, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
# Since they have same Happiness Score I assume that okey to get same rank
world_hap2015[world_hap2015['Happiness Rank'].duplicated(keep = False)]
# Out:
#        Country                           Region  Happiness Rank  \
# 81      Jordan  Middle East and Northern Africa              82
# 82  Montenegro       Central and Eastern Europe              82
#
#     Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 81            5.192         0.04524                   0.90198  1.05392
# 82            5.192         0.05235                   0.97438  0.90557
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 81                   0.69639  0.40661                        0.14293
# 82                   0.72521  0.18260                        0.14296
#
#     Generosity  Dystopia Residual
# 81     0.11053            1.87996
# 82     0.16140            2.10017

# %%
world_hap2015[world_hap2015[['Country', 'Happiness Rank']].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Standard Error, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
world_hap2016[world_hap2016.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Lower Confidence Interval, Upper Confidence Interval, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
world_hap2016[world_hap2016['Happiness Rank'].duplicated(keep = False)]
# same thing goes here
# Out:
#           Country                           Region  Happiness Rank  \
# 33   Saudi Arabia  Middle East and Northern Africa              34
# 34         Taiwan                     Eastern Asia              34
# 56         Poland       Central and Eastern Europe              57
# 57    South Korea                     Eastern Asia              57
# 144  Burkina Faso               Sub-Saharan Africa             145
# 145        Uganda               Sub-Saharan Africa             145
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 33             6.379                      6.287                      6.471
# 34             6.379                      6.305                      6.453
# 56             5.835                      5.749                      5.921
# 57             5.835                      5.747                      5.923
# 144            3.739                      3.647                      3.831
# 145            3.739                      3.629                      3.849
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 33                    1.48953  0.84829                   0.59267  0.37904
# 34                    1.39729  0.92624                   0.79565  0.32377
# 56                    1.24585  1.04685                   0.69058  0.45190
# 57                    1.35948  0.72194                   0.88645  0.25168
# 144                   0.31995  0.63054                   0.21297  0.33370
# 145                   0.34719  0.90981                   0.19625  0.43653
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 33                         0.30008     0.15457            2.61482
# 34                         0.06630     0.25495            2.61523
# 56                         0.05500     0.14443            2.20035
# 57                         0.07716     0.18824            2.35015
# 144                        0.12533     0.24353            1.87319
# 145                        0.06442     0.27102            1.51416

# %%
world_hap2016[world_hap2016[['Country', 'Happiness Rank']].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Lower Confidence Interval, Upper Confidence Interval, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
world_hap2015[world_hap2015['Country'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Standard Error, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
world_hap2016[world_hap2016.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Lower Confidence Interval, Upper Confidence Interval, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
world_hap2017[world_hap2017[['Country', 'Happiness.Rank']].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Country, Happiness.Rank, Happiness.Score, Whisker.high, Whisker.low, Economy..GDP.per.Capita., Family, Health..Life.Expectancy., Freedom, Generosity, Trust..Government.Corruption., Dystopia.Residual]
# Index: []

# %%
world_hap2017[world_hap2017['Country'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Country, Happiness.Rank, Happiness.Score, Whisker.high, Whisker.low, Economy..GDP.per.Capita., Family, Health..Life.Expectancy., Freedom, Generosity, Trust..Government.Corruption., Dystopia.Residual]
# Index: []

# %%
world_hap2017[world_hap2017['Happiness.Rank'].duplicated(keep = False)]
# Out:
# Empty DataFrame
# Columns: [Country, Happiness.Rank, Happiness.Score, Whisker.high, Whisker.low, Economy..GDP.per.Capita., Family, Health..Life.Expectancy., Freedom, Generosity, Trust..Government.Corruption., Dystopia.Residual]
# Index: []

# %% [markdown]
# #### 6. Completeness:
# Ensure that no critical data is missing. This might mean checking for null values or required fields that are empty.
#
# We will start by checking the dataset for missing or null values. For this, we can use the isna() method which returns a dataframe of boolean values indicating if a field is null or not. To group all missing values by column, we can include the sum() method.

# %%
# Display number missing values per column
# As we see there no NaN
world_hap2015.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
# Display number missing values per column
# As we see there no NaN
world_hap2016.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Lower Confidence Interval        0
# Upper Confidence Interval        0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
# Display number missing values per column
# As we see there no NaN
world_hap2017.isnull().sum()
# Out:
# Country                          0
# Happiness.Rank                   0
# Happiness.Score                  0
# Whisker.high                     0
# Whisker.low                      0
# Economy..GDP.per.Capita.         0
# Family                           0
# Health..Life.Expectancy.         0
# Freedom                          0
# Generosity                       0
# Trust..Government.Corruption.    0
# Dystopia.Residual                0
# dtype: int64

# %%
# Display number missing values per column
# As we see there "one" NaN
world_hap2018.isnull().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       1
# dtype: int64

# %%
# Filter the row that have Null 
world_hap2018[world_hap2018.isnull().any(axis=1)]
# Out:
#     Overall rank     Country or region  Score  GDP per capita  Social support  \
# 19            20  United Arab Emirates  6.774           2.096           0.776
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 19                     0.67                         0.284       0.186
#
#     Perceptions of corruption
# 19                        NaN

# %%
# Replace the NaN in the column Perceptions of corruption with const 0.0 since the dtype is float
missing_index = world_hap2018["Perceptions of corruption"].isnull().index

world_hap2018.loc[missing_index, "Perceptions of corruption" ] = world_hap2018.loc[missing_index, "Perceptions of corruption"].fillna(0.0)

# %%
# No NaN values left in the DataFrame
world_hap2018[world_hap2018.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %%
# Display number missing values per column
# As we see there no NaN
world_hap2019.isnull().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
# To check if the dataset have "-"
# The Output will be the sum of the row that don't have "-"
typo_wrong = (world_hap2015.notna()) & (world_hap2015 != '-')
typo_wrong.sum(axis=0)
# Out:
# Country                          158
# Region                           158
# Happiness Rank                   158
# Happiness Score                  158
# Standard Error                   158
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         158
# Freedom                          158
# Trust (Government Corruption)    158
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %%
# To check if the dataset have "-"
# The Output will be the sum of the row that don't have "-"
typo_wrong = (world_hap2016.notna()) & (world_hap2016 != '-')
typo_wrong.sum(axis=0)
# Out:
# Country                          157
# Region                           157
# Happiness Rank                   157
# Happiness Score                  157
# Lower Confidence Interval        157
# Upper Confidence Interval        157
# Economy (GDP per Capita)         157
# Family                           157
# Health (Life Expectancy)         157
# Freedom                          157
# Trust (Government Corruption)    157
# Generosity                       157
# Dystopia Residual                157
# dtype: int64

# %%
# To check if the dataset have "-"
# The Output will be the sum of the row that don't have "-"
typo_wrong = (world_hap2017.notna()) & (world_hap2017 != '-')
typo_wrong.sum(axis=0)
# Out:
# Country                          155
# Happiness.Rank                   155
# Happiness.Score                  155
# Whisker.high                     155
# Whisker.low                      155
# Economy..GDP.per.Capita.         155
# Family                           155
# Health..Life.Expectancy.         155
# Freedom                          155
# Generosity                       155
# Trust..Government.Corruption.    155
# Dystopia.Residual                155
# dtype: int64

# %%
# To check if the dataset have "-"
# The Output will be the sum of the row that don't have "-"
typo_wrong = (world_hap2018.notna()) & (world_hap2018 != '-')
typo_wrong.sum(axis=0)
# Out:
# Overall rank                    156
# Country or region               156
# Score                           156
# GDP per capita                  156
# Social support                  156
# Healthy life expectancy         156
# Freedom to make life choices    156
# Generosity                      156
# Perceptions of corruption       156
# dtype: int64

# %%
# To check if the dataset have "-"
# The Output will be the sum of the row that don't have "-"
typo_wrong = (world_hap2019.notna()) & (world_hap2019 != '-')
typo_wrong.sum(axis=0)
# Out:
# Overall rank                    156
# Country or region               156
# Score                           156
# GDP per capita                  156
# Social support                  156
# Healthy life expectancy         156
# Freedom to make life choices    156
# Generosity                      156
# Perceptions of corruption       156
# dtype: int64

# %% [markdown]
# #### 7. Check Accuracy:
#
# Verify that the data is correct and precise. This could involve comparing data samples with known sources or using validation rules.
#
# **The process includes:**
# 1. Validating the appropriateness of data types for the dataset.
# 2. Identifying outliers  using established validation  rule

# %%
world_hap2015.head(2)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201

# %%
# Data Types of world_hap2015
world_hap2015.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
# world_hap2015: All columns are resample the intent format and compatible with logic meaning

# %%
world_hap2016.head(2)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# 1                        0.41203     0.28083            2.69463

# %%
# Data Types of world_hap2016
world_hap2016.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Lower Confidence Interval        float64
# Upper Confidence Interval        float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
# world_hap2016:  Also All columns are resample the intent format and compatible with logic meaning

# %%
world_hap2017.head(2)
# Out:
#    Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0   Norway               1            7.537      7.594445     7.479556
# 1  Denmark               2            7.522      7.581728     7.462272
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707

# %%
# Data Types of world_hap2017
world_hap2017.dtypes
# Out:
# Country                           object
# Happiness.Rank                     int64
# Happiness.Score                  float64
# Whisker.high                     float64
# Whisker.low                      float64
# Economy..GDP.per.Capita.         float64
# Family                           float64
# Health..Life.Expectancy.         float64
# Freedom                          float64
# Generosity                       float64
# Trust..Government.Corruption.    float64
# Dystopia.Residual                float64
# dtype: object

# %%
new_column_names = {
    'Country': 'Country',
    'Happiness.Rank': 'Happiness Rank',
    'Happiness.Score': 'Happiness Score',
    'Whisker.high': 'Upper Confidence Interval',
    'Whisker.low': 'Lower Confidence Interval',
    'Economy..GDP.per.Capita.': 'Economy GDP per Capita',
    'Family': 'Family',
    'Health..Life.Expectancy.': 'Health Life Expectancy',
    'Freedom': 'Freedom',
    'Generosity': 'Generosity',
    'Trust..Government.Corruption.': 'Trust Government Corruption',
    'Dystopia.Residual': 'Dystopia Residual'
}

# Rename the columns
world_hap2017.rename(columns=new_column_names, inplace=True)

# %%
# Round the columns to 3 decimal places as in world_hap2016
world_hap2017[['Lower Confidence Interval', 'Upper Confidence Interval']] = world_hap2017[['Lower Confidence Interval', 'Upper Confidence Interval']].round(3)

# %%
world_hap2017.head(2)
# Out:
#    Country  Happiness Rank  Happiness Score  Upper Confidence Interval  \
# 0   Norway               1            7.537                      7.594
# 1  Denmark               2            7.522                      7.582
#
#    Lower Confidence Interval  Economy GDP per Capita    Family  \
# 0                      7.480                1.616463  1.533524
# 1                      7.462                1.482383  1.551122
#
#    Health Life Expectancy   Freedom  Generosity  Trust Government Corruption  \
# 0                0.796667  0.635423    0.362012                     0.315964
# 1                0.792566  0.626007    0.355280                     0.400770
#
#    Dystopia Residual
# 0           2.277027
# 1           2.313707

# %%
# world_hap2017: All columns are resample the intent format and compatible with logic meaning

# %%
world_hap2018.head(2)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340

# %%
world_hap2018.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
column_2018 = {
    'Overall rank': 'Happiness Rank',
    'Country or region': 'Country',
    'Score': 'Happiness Score',
    'GDP per capita': 'Economy GDP per Capita',
    'Social support': 'Family',
    'Healthy life expectancy': 'Health Life Expectancy',
    'Freedom to make life choices': 'Freedom',
    'Generosity': 'Generosity',
    'Perceptions of corruption': 'Trust Government Corruption'
}

# Rename the columns
world_hap2018.rename(columns=column_2018, inplace=True)

# %%
world_hap2018.head(2)
# Out:
#    Happiness Rank  Country  Happiness Score  Economy GDP per Capita  Family  \
# 0               1  Finland            7.632                   1.305   1.592
# 1               2   Norway            7.594                   1.456   1.582
#
#    Health Life Expectancy  Freedom  Generosity  Trust Government Corruption
# 0                   0.874    0.681       0.202                        0.393
# 1                   0.861    0.686       0.286                        0.340

# %%
# world_hap2018: All columns are resample the intent format and compatible with logic meaning

# %%
world_hap2019.head(2)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410

# %%
world_hap2019.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
column_2019 = {
    'Overall rank': 'Happiness Rank',
    'Country or region': 'Country',
    'Score': 'Happiness Score',
    'GDP per capita': 'Economy GDP per Capita',
    'Social support': 'Family',
    'Healthy life expectancy': 'Health Life Expectancy',
    'Freedom to make life choices': 'Freedom',
    'Generosity': 'Generosity',
    'Perceptions of corruption': 'Trust Government Corruption'
}

# Rename the columns
world_hap2019.rename(columns=column_2019, inplace=True)

# %%
world_hap2019.head(2)
# Out:
#    Happiness Rank  Country  Happiness Score  Economy GDP per Capita  Family  \
# 0               1  Finland            7.769                   1.340   1.587
# 1               2  Denmark            7.600                   1.383   1.573
#
#    Health Life Expectancy  Freedom  Generosity  Trust Government Corruption
# 0                   0.986    0.596       0.153                        0.393
# 1                   0.996    0.592       0.252                        0.410

# %%
# world_hap2019: All columns are resample the intent format and compatible with logic meaning

# %%
# check outliers 
# Get top 5 countries based on Happiness Rank for each year
for year, df in zip(["2015", "2016", "2017"], 
                    [world_hap2015, world_hap2016, world_hap2017, world_hap2018, world_hap2019]):
    print(f"Top Countries in {year}:")
    print(df.nsmallest(5, "Happiness Rank")[["Country", "Happiness Rank", "Happiness Score"]])
    print("\n")

# For the factors, find the top country in each contributing factor in 2019
factors = ["Economy (GDP per Capita)", "Family", "Health (Life Expectancy)", "Freedom", 
           "Trust (Government Corruption)", "Generosity"]
# Out:
# Top Countries in 2015:
#        Country  Happiness Rank  Happiness Score
# 0  Switzerland               1            7.587
# 1      Iceland               2            7.561
# 2      Denmark               3            7.527
# 3       Norway               4            7.522
# 4       Canada               5            7.427
#
#
# Top Countries in 2016:
#        Country  Happiness Rank  Happiness Score
# 0      Denmark               1            7.526
# 1  Switzerland               2            7.509
# 2      Iceland               3            7.501
# 3       Norway               4            7.498
# 4      Finland               5            7.413
#
#
# Top Countries in 2017:
#        Country  Happiness Rank  Happiness Score
# 0       Norway               1            7.537
# 1      Denmark               2            7.522
# 2      Iceland               3            7.504
# 3  Switzerland               4            7.494
# 4      Finland               5            7.469

# %%
# Top 10 countries by happiness score for each year
top_countries_2015 = world_hap2015.nlargest(10, "Happiness Score")
top_countries_2016 = world_hap2016.nlargest(10, "Happiness Score")
top_countries_2017 = world_hap2017.nlargest(10, "Happiness Score")

# Combine data for a single plot
top_countries_2015['Year'] = '2015'
top_countries_2016['Year'] = '2016'
top_countries_2017['Year'] = '2017'
top_countries_combined = pd.concat([top_countries_2015[['Country', 'Happiness Score', 'Year']],
                                    top_countries_2016[['Country', 'Happiness Score', 'Year']],
                                    top_countries_2017[['Country', 'Happiness Score', 'Year']]])

# just Plot
plt.figure(figsize=(10, 6))
sns.barplot(x="Happiness Score", y="Country", data=top_countries_combined, hue="Year", palette="husl")
plt.title("Top 10 Happiest Countries (2015-2017)")
plt.xticks(rotation=45)
plt.show()

# %%
## 2015 scatter
# 1. Scatter Plot for 2015: Happiness Score vs Economy (GDP per Capita)
# In this plot, we are visualizing the relationship between two variables:
# - Economy (GDP per Capita) and Happiness Score for the year 2015.
# We will use this scatter plot to identify any potential outliers in the data,
# such as countries with unusually high or low happiness scores despite their economy.
plt.figure(figsize=(10, 6))
sns.scatterplot(x="Economy (GDP per Capita)", y="Happiness Score", data=world_hap2015)
plt.title("Happiness Score vs Economy (2015)")
plt.xlabel("Economy (GDP per Capita)")
plt.ylabel("Happiness Score")
plt.show()

# %%
## 2016 scatter
# 2. Scatter Plot for 2016: Happiness Score vs Economy (GDP per Capita)
# This plot shows the same relationship as the 2015 plot, but for the year 2016.
# By comparing the plots across the years, we can see if any trends or outliers persist over time.
plt.figure(figsize=(10, 6))
sns.scatterplot(x="Economy (GDP per Capita)", y="Happiness Score", data=world_hap2016)
plt.title("Happiness Score vs Economy (2016)")
plt.xlabel("Economy (GDP per Capita)")
plt.ylabel("Happiness Score")
plt.show()

# %%
## 2017 scatter
# 3. Scatter Plot for 2017: Happiness Score vs Economy (GDP per Capita)
# This plot is similar to the previous ones, but for the year 2017.
# The scatter plots for each year will help us identify any outliers and track how countries' happiness scores
# evolve over the years relative to their economy.
plt.figure(figsize=(10, 6))
sns.scatterplot(x="Economy GDP per Capita", y="Happiness Score", data=world_hap2017)
plt.title("Happiness Score vs Economy (2017)")
plt.xlabel("Economy (GDP per Capita)")
plt.ylabel("Happiness Score")
plt.show()

# %%
# Box Plot for Happiness Score in 2015
plt.figure(figsize=(10, 6))
sns.boxplot(x=world_hap2015["Happiness Score"])
plt.title("Happiness Score Distribution (2015)")
plt.xlabel("Happiness Score")
plt.show()

# Box Plot for Economy (GDP per Capita) in 2015
plt.figure(figsize=(10, 6))
sns.boxplot(x=world_hap2015["Economy (GDP per Capita)"])
plt.title("Economy (GDP per Capita) Distribution (2015)")
plt.xlabel("Economy (GDP per Capita)")
plt.show()

# %%
# Box Plot for Happiness Score in 2016
plt.figure(figsize=(10, 6))
sns.boxplot(x=world_hap2016["Happiness Score"])
plt.title("Happiness Score Distribution (2016)")
plt.xlabel("Happiness Score")
plt.show()

# Box Plot for Economy (GDP per Capita) in 2016
plt.figure(figsize=(10, 6))
sns.boxplot(x=world_hap2016["Economy (GDP per Capita)"])
plt.title("Economy (GDP per Capita) Distribution (2016)")
plt.xlabel("Economy (GDP per Capita)")
plt.show()

# %%
# Box Plot for Happiness Score in 2017
plt.figure(figsize=(10, 6))
sns.boxplot(x=world_hap2017["Happiness Score"])
plt.title("Happiness Score Distribution (2017)")
plt.xlabel("Happiness Score")
plt.show()

# Box Plot for Economy (GDP per Capita) in 2017
plt.figure(figsize=(10, 6))
sns.boxplot(x=world_hap2017["Economy GDP per Capita"])
plt.title("Economy (GDP per Capita) Distribution (2017)")
plt.xlabel("Economy (GDP per Capita)")
plt.show()

# %%
# Box Plot for Happiness Score in 2018
plt.figure(figsize=(10, 6))
sns.boxplot(x=world_hap2018["Happiness Score"])
plt.title("Happiness Score Distribution (2018)")
plt.xlabel("Happiness Score")
plt.show()

# Box Plot for Economy (GDP per Capita) in 2018
plt.figure(figsize=(10, 6))
sns.boxplot(x=world_hap2018["Economy GDP per Capita"])
plt.title("Economy (GDP per Capita) Distribution (2018)")
plt.xlabel("Economy (GDP per Capita)")
plt.show()

# %%
# Box Plot for Happiness Score in 2019
plt.figure(figsize=(10, 6))
sns.boxplot(x=world_hap2019["Happiness Score"])
plt.title("Happiness Score Distribution (2019)")
plt.xlabel("Happiness Score")
plt.show()

# Box Plot for Economy (GDP per Capita) in 2019
plt.figure(figsize=(10, 6))
sns.boxplot(x=world_hap2019["Economy GDP per Capita"])
plt.title("Economy (GDP per Capita) Distribution (2019)")
plt.xlabel("Economy (GDP per Capita)")
plt.show()

# %%
years = [2015, 2016, 2017, 2018, 2019]
dataframes = [world_hap2015, world_hap2016, world_hap2017, world_hap2018, world_hap2019]

plt.figure(figsize=(15, 10))

for i, (year, df) in enumerate(zip(years, dataframes), 1):
    plt.subplot(3, 2, i)
    sns.histplot(df["Happiness Score"], bins=30, kde=True)
    plt.title(f"Happiness Score Distribution ({year})")
    plt.xlabel("Happiness Score")
    plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
# No significant outliers in the Happiness Score for 2015 - 2019 in Happiness Score Distribution

# %% [markdown]
# # What countries or regions rank the highest in overall happiness and each ofthe six factors contributing to happiness?

# %%
# Select the top 10 countries by happiness rank for each year (lower rank is better)
top_countries_2015 = world_hap2015.nsmallest(10, "Happiness Rank")
top_countries_2016 = world_hap2016.nsmallest(10, "Happiness Rank")
top_countries_2017 = world_hap2017.nsmallest(10, "Happiness Rank")

top_countries_2018 = world_hap2018.nsmallest(10, "Happiness Rank")
top_countries_2019 = world_hap2019.nsmallest(10, "Happiness Rank")

# Add year column
top_countries_2015['Year'] = '2015'
top_countries_2016['Year'] = '2016'
top_countries_2017['Year'] = '2017'
top_countries_2018['Year'] = '2018'
top_countries_2019['Year'] = '2019'

# Combine data for 2015-2017
top_countries_combined_15_17 = pd.concat([
    top_countries_2015[['Country', 'Happiness Rank', 'Year']],
    top_countries_2016[['Country', 'Happiness Rank', 'Year']],
    top_countries_2017[['Country', 'Happiness Rank', 'Year']]
])

# Combine data for 2018-2019
top_countries_combined_18_19 = pd.concat([
    top_countries_2018[['Country', 'Happiness Rank', 'Year']],
    top_countries_2019[['Country', 'Happiness Rank', 'Year']]
])

# Plot 1: Top 10 Happiest Countries (2015-2017)
plt.figure(figsize=(12, 6))
sns.barplot(x="Happiness Rank", y="Country", data=top_countries_combined_15_17, hue="Year",
            palette=['#171266', '#66b3ff', '#99ff99'])  # Custom colors
plt.title("Top 10 Happiest Countries (2015-2017)")
plt.xlabel("Happiness Rank (Lower is Better)")
plt.ylabel("Country")
plt.xticks(rotation=45)
plt.legend(title="Year")
plt.tight_layout()
plt.show()

# Plot 2: Top 10 Happiest Countries (2018-2019)
plt.figure(figsize=(12, 6))
sns.barplot(x="Happiness Rank", y="Country", data=top_countries_combined_18_19, hue="Year",
            palette=['#000000', '#ff6600'])  # Custom colors
plt.title("Top 10 Happiest Countries (2018-2019)")
plt.xlabel("Happiness Rank (Lower is Better)")
plt.ylabel("Country")
plt.xticks(rotation=45)
plt.legend(title="Year")
plt.tight_layout()
plt.show()

# %% [markdown]
# # How did country ranks or scores change between the 2015 and 2016 as well as the 2016 and 2017 reports?

# %%
# Select top 10 happiest countries for each year based on rank
top_2015 = world_hap2015.nsmallest(10, "Happiness Rank")[['Country', 'Happiness Rank']].reset_index(drop=True)
top_2016 = world_hap2016.nsmallest(10, "Happiness Rank")[['Country', 'Happiness Rank']].reset_index(drop=True)
top_2017 = world_hap2017.nsmallest(10, "Happiness Rank")[['Country', 'Happiness Rank']].reset_index(drop=True)

# Add year information
top_2015['Year'] = 2015
top_2016['Year'] = 2016
top_2017['Year'] = 2017

# Combine data for each period separately
ranking_2015_2016 = pd.concat([top_2015, top_2016])
ranking_2016_2017 = pd.concat([top_2016, top_2017])

# Set figure
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Plot for 2015-2016
sns.lineplot(data=ranking_2015_2016, x='Year', y='Happiness Rank', hue='Country', marker='o', linewidth=2, ax=axes[0])
axes[0].set_title("Happiness Rank Changes (2015-2016)")
axes[0].set_xlabel("Year")
axes[0].set_ylabel("Happiness Rank")
axes[0].invert_yaxis()  # Lower rank is better, so invert y-axis
axes[0].grid(True, linestyle="--", alpha=0.6)

# Plot for 2016-2017
sns.lineplot(data=ranking_2016_2017, x='Year', y='Happiness Rank', hue='Country', marker='o', linewidth=2, ax=axes[1])
axes[1].set_title("Happiness Rank Changes (2016-2017)")
axes[1].set_xlabel("Year")
axes[1].set_ylabel("Happiness Rank")
axes[1].invert_yaxis()  # Lower rank is better
axes[1].grid(True, linestyle="--", alpha=0.6)

# Adjust layout and show plot
plt.tight_layout()
plt.show()

# %%
# Select top 10 happiest countries for each year
top_2015 = world_hap2015.nlargest(10, "Happiness Score")[['Country', 'Happiness Score']].reset_index(drop=True)
top_2016 = world_hap2016.nlargest(10, "Happiness Score")[['Country', 'Happiness Score']].reset_index(drop=True)
top_2017 = world_hap2017.nlargest(10, "Happiness Score")[['Country', 'Happiness Score']].reset_index(drop=True)

# Add year information
top_2015['Year'] = 2015
top_2016['Year'] = 2016
top_2017['Year'] = 2017

# Combine into one dataframe
ranking_changes = pd.concat([top_2015, top_2016, top_2017])

# Plot
plt.figure(figsize=(12, 6))
sns.lineplot(data=ranking_changes, x='Year', y='Happiness Score', hue='Country', marker='o', linewidth=2)

# Chart details
plt.title("Happiness Score Changes (2015-2017)")
plt.xlabel("Year")
plt.ylabel("Happiness Score")
plt.legend(title="Country", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, linestyle="--", alpha=0.6)

# Show the plot
plt.show()

# %% [markdown]
# # Did any country experience a significant increase or decrease in happiness?

# %%
# Display the rank positions for 2015 and 2019 alongside the rank difference
rank_table = significant_change[['Happiness Rank_2015', 'Happiness Rank_2019', 'Rank Difference']]

# Apply styling to improve table design with custom colors
styled_table = rank_table.style.format({
    'Happiness Rank_2015': '{:,.0f}',
    'Happiness Rank_2019': '{:,.0f}',
    'Rank Difference': '{:+,.0f}'
}).background_gradient(axis=None, cmap='RdYlGn') \
  .set_table_styles([
    {'selector': 'thead th', 'props': [('background-color', '#000000'), ('color', 'white'), ('font-weight', 'bold')]},  # Black header
    {'selector': 'tbody tr:nth-child(even)', 'props': [('background-color', '#ff6600')]},  # Orange for even rows
    {'selector': 'tbody tr:nth-child(odd)', 'props': [('background-color', '#ffffff')]},  # White for odd rows
    {'selector': 'td', 'props': [('padding', '10px'), ('text-align', 'center')]},  # Cell padding and alignment
    {'selector': 'table', 'props': [('border-collapse', 'collapse'), ('width', '100%'), ('border', '1px solid #ddd')]}  # Table borders
])

# Display the styled table
styled_table
# Out:
# <style type="text/css">
# #T_a5685 thead th {
#   background-color: #000000;
#   color: white;
#   font-weight: bold;
# }
# #T_a5685 tbody tr:nth-child(even) {
#   background-color: #ff6600;
# }
# #T_a5685 tbody tr:nth-child(odd) {
#   background-color: #ffffff;
# }
# #T_a5685 td {
#   padding: 10px;
#   text-align: center;
# }
# #T_a5685 table {
#   border-collapse: collapse;
#   width: 100%;
#   border: 1px solid #ddd;
# }
# #T_a5685_row0_col0, #T_a5685_row76_col2 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_a5685_row0_col1, #T_a5685_row3_col0, #T_a5685_row81_col2 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_a5685_row0_col2, #T_a5685_row35_col2, #T_a5685_row45_col2, #T_a5685_row52_col2 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_a5685_row1_col0, #T_a5685_row1_col2, #T_a5685_row47_col2, #T_a5685_row73_col2 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_a5685_row1_col1 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_a5685_row2_col0 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_a5685_row2_col1, #T_a5685_row93_col2 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_a5685_row2_col2, #T_a5685_row12_col2 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_a5685_row3_col1 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_a5685_row3_col2, #T_a5685_row46_col1, #T_a5685_row53_col0 {
#   background-color: #bde379;
#   color: #000000;
# }
# #T_a5685_row4_col0 {
#   background-color: #fece7c;
#   color: #000000;
# }
# #T_a5685_row4_col1, #T_a5685_row10_col0, #T_a5685_row66_col2 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_a5685_row4_col2, #T_a5685_row9_col2, #T_a5685_row23_col2, #T_a5685_row25_col2, #T_a5685_row48_col2 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_a5685_row5_col0, #T_a5685_row14_col1, #T_a5685_row80_col2 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_a5685_row5_col1, #T_a5685_row8_col0, #T_a5685_row79_col2 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_a5685_row5_col2, #T_a5685_row26_col2, #T_a5685_row64_col2, #T_a5685_row86_col2 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_a5685_row6_col0 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_a5685_row6_col1, #T_a5685_row7_col2, #T_a5685_row40_col2, #T_a5685_row72_col2 {
#   background-color: #fdbd6d;
#   color: #000000;
# }
# #T_a5685_row6_col2, #T_a5685_row36_col2, #T_a5685_row51_col2 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_a5685_row7_col0, #T_a5685_row12_col1 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_a5685_row7_col1, #T_a5685_row20_col0, #T_a5685_row62_col2 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_a5685_row8_col1, #T_a5685_row38_col2, #T_a5685_row88_col2 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_a5685_row8_col2, #T_a5685_row27_col2, #T_a5685_row87_col2, #T_a5685_row89_col2 {
#   background-color: #f36b42;
#   color: #f1f1f1;
# }
# #T_a5685_row9_col0 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_a5685_row9_col1, #T_a5685_row17_col0 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_a5685_row10_col1, #T_a5685_row24_col0 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_a5685_row10_col2, #T_a5685_row43_col2 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_a5685_row11_col0, #T_a5685_row16_col1 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_a5685_row11_col1, #T_a5685_row82_col2 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_a5685_row11_col2, #T_a5685_row16_col2, #T_a5685_row18_col2, #T_a5685_row77_col2, #T_a5685_row107_col2 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_a5685_row12_col0, #T_a5685_row22_col1 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_a5685_row13_col0, #T_a5685_row21_col1 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_a5685_row13_col1, #T_a5685_row31_col2, #T_a5685_row75_col2 {
#   background-color: #fec877;
#   color: #000000;
# }
# #T_a5685_row13_col2 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_a5685_row14_col0, #T_a5685_row18_col1 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_a5685_row14_col2 {
#   background-color: #f16640;
#   color: #f1f1f1;
# }
# #T_a5685_row15_col0 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_a5685_row15_col1, #T_a5685_row23_col0 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_a5685_row15_col2, #T_a5685_row19_col2, #T_a5685_row60_col2, #T_a5685_row85_col2 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_a5685_row16_col0, #T_a5685_row28_col1 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_a5685_row17_col1 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_a5685_row17_col2, #T_a5685_row78_col2 {
#   background-color: #ec5c3b;
#   color: #f1f1f1;
# }
# #T_a5685_row18_col0, #T_a5685_row29_col1 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_a5685_row19_col0, #T_a5685_row39_col1 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_a5685_row19_col1, #T_a5685_row30_col0 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_a5685_row20_col1, #T_a5685_row26_col0 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_a5685_row20_col2, #T_a5685_row30_col2, #T_a5685_row46_col2, #T_a5685_row74_col2, #T_a5685_row83_col2, #T_a5685_row100_col2, #T_a5685_row101_col2 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_a5685_row21_col0, #T_a5685_row37_col1 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_a5685_row21_col2, #T_a5685_row29_col2, #T_a5685_row68_col2, #T_a5685_row108_col2 {
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# #T_a5685_row22_col0 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_a5685_row22_col2, #T_a5685_row28_col2, #T_a5685_row41_col2, #T_a5685_row49_col2 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_a5685_row23_col1, #T_a5685_row33_col0 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_a5685_row24_col1, #T_a5685_row41_col0 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_a5685_row24_col2, #T_a5685_row33_col2, #T_a5685_row44_col2, #T_a5685_row50_col2, #T_a5685_row90_col2 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_a5685_row25_col0, #T_a5685_row53_col2, #T_a5685_row57_col1 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_a5685_row25_col1, #T_a5685_row35_col0 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_a5685_row26_col1, #T_a5685_row32_col0 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_a5685_row27_col0, #T_a5685_row42_col1 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_a5685_row27_col1 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_a5685_row28_col0, #T_a5685_row36_col1 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_a5685_row29_col0, #T_a5685_row41_col1 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_a5685_row30_col1, #T_a5685_row36_col0 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_a5685_row31_col0, #T_a5685_row70_col1 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_a5685_row31_col1, #T_a5685_row49_col0 {
#   background-color: #c7e77f;
#   color: #000000;
# }
# #T_a5685_row32_col1 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_a5685_row32_col2, #T_a5685_row67_col2 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_a5685_row33_col1, #T_a5685_row48_col0 {
#   background-color: #c9e881;
#   color: #000000;
# }
# #T_a5685_row34_col0, #T_a5685_row69_col1 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_a5685_row34_col1, #T_a5685_row44_col0 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_a5685_row34_col2 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_a5685_row35_col1 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_a5685_row37_col0, #T_a5685_row49_col1 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_a5685_row37_col2, #T_a5685_row42_col2, #T_a5685_row61_col2 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_a5685_row38_col0 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_a5685_row38_col1, #T_a5685_row56_col0 {
#   background-color: #b5df74;
#   color: #000000;
# }
# #T_a5685_row39_col0, #T_a5685_row58_col1 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_a5685_row39_col2 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_a5685_row40_col0, #T_a5685_row55_col1 {
#   back

# %%
# Select the countries and their happiness ranks for 2015 and 2019
rank_2015 = world_hap2015[['Country', 'Happiness Rank']].set_index('Country')
rank_2019 = world_hap2019[['Country', 'Happiness Rank']].set_index('Country')

# Merge the two DataFrames to calculate the difference in ranks between 2015 and 2019
rank_change = pd.merge(rank_2015, rank_2019, left_index=True, right_index=True, suffixes=('_2015', '_2019'))
rank_change['Rank Difference'] = rank_change['Happiness Rank_2019'] - rank_change['Happiness Rank_2015']

# Filter for significant changes (rank difference greater than 5 in either direction)
significant_change = rank_change[rank_change['Rank Difference'].abs() > 5]

# Split into increase and decrease
increase = significant_change[significant_change['Rank Difference'] < 0]  # Countries with increase in happiness
decrease = significant_change[significant_change['Rank Difference'] > 0]  # Countries with decrease in happiness

# Plot the countries with a significant increase in happiness
plt.figure(figsize=(12, 6))
sns.barplot(x=increase.index, y='Rank Difference', data=increase, palette='Blues_d')
plt.title("Countries with Significant Increase in Happiness (2015 to 2019)")
plt.xlabel("Country")
plt.ylabel("Rank Difference (Negative = Increase)")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# Plot the countries with a significant decrease in happiness
plt.figure(figsize=(12, 6))
sns.barplot(x=decrease.index, y='Rank Difference', data=decrease, palette='Reds_d')
plt.title("Countries with Significant Decrease in Happiness (2015 to 2019)")
plt.xlabel("Country")
plt.ylabel("Rank Difference (Positive = Decrease)")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **What is an Outlier?**
# Outlier is an row/observation that appears far away and diverges from an overall pattern in a sample.
#
# **What are the types of Outliers?**
# 1. Univariate: These outliers can be found when we look at distribution of a single variable
# 2. Multivariate: are outliers in an n-dimensional space. In order to find them, you have to look at distributions in multi-dimensions. example (hight=100, weight=100) for a person
#
# **What causes Outliers?**
# Whenever we come across outliers, the ideal way to tackle them is to find out the reason of having these outliers. The method to deal with them would then depend on the reason of their occurrence.
#
# Let’s understand various types of outliers:
#
# 1. Data Entry Errors:- Human errors such as errors caused during data collection, recording, or entry can cause outliers in data.
# 2. Measurement Error: It is the most common source of outliers. This is caused when the measurement instrument used turns out to be faulty.
# 3. Data Processing Error: Whenever we perform data mining, we extract data from multiple sources. It is possible that some manipulation or extraction errors may lead to outliers in the dataset.
# 4. Sampling error: For instance, we have to measure the height of athletes. By mistake, we include a few basketball players in the sample. This inclusion is likely to cause outliers in the dataset.
# 5. Natural Outlier: When an outlier is not artificial (due to error), it is a natural outlier. For instance: In my last assignment with one of the renowned insurance company, I noticed that the performance of top 50 financial advisors was far higher than rest of the population. Surprisingly, it was not due to any error. Hence, whenever we perform any data mining activity with advisors, we used to treat this segment separately.
#
#
# **What is the impact of Outliers on a dataset?**
#
#
# ![image.png](https://www.analyticsvidhya.com/wp-content/uploads/2015/02/Outlier_31.png)
#
#
#
# **How to detect Outliers?**
#
# 1. Most commonly used method to detect outliers is visualization (Univariate Graphical Analysis).
#
# We use 3 common visualization methods:
# >- Box-plot: A box plot is a method for graphically depicting groups of numerical data through their quartiles. The box extends from the Q1 to Q3 quartile values of the data, with a line at the median (Q2). The whiskers extend from the edges of the box to show the range of the data. Outlier points are those past the end of the whiskers. Box plots show robust measures of location and spread as well as providing information about symmetry and outliers.
# >
# >
# >![image.png](https://miro.medium.com/v2/resize:fit:698/format:webp/1*VK5iHA2AB28HSZwWwUbNYg.png)
# >
# >
# >- Histogram
# >- Scatter Plot: A scatter plot is a mathematical diagram using Cartesian coordinates to display values for two variables for a set of data. The data are displayed as a collection of points, each having the value of one variable determining the position on the horizontal axis and the value of the other variable determining the position on the vertical axis. The points that are far from the population can be termed as an outlier.
# >
# >
# >![image.png](https://miro.medium.com/v2/resize:fit:4800/format:webp/1*Ov6aH-8yIwNoUxtMFwgx4g.png)
# >
# >
#
# 2. Using statistical method (Univariate Non-Graphical analysis):
# >- Any value, which is beyond the range of -1.5 x IQR to 1.5 x IQR
#
# ![image.png](https://www.whatissixsigma.net/wp-content/uploads/2015/07/Box-Plot-Diagram-to-identify-Outliers-figure-1.png)
#
# >- Use capping methods. Any value which out of range of 5th and 95th percentile can be considered as outlier
# >- Data points, three or more standard deviation away from mean are considered outlier: The Z-score is the signed number of standard deviations by which the value of an observation or data point is above the mean value of what is being observed or measured. While calculating the Z-score we re-scale and center the data and look for data points that are too far from zero. These data points which are way too far from zero will be treated as the outliers. In most of the cases, a threshold of 3 or -3 is used i.e if the Z-score value is greater than or less than 3 or -3 respectively, that data point will be identified as outliers.
# > - Outlier detection is merely a special case of the examination of data for influential data points and it also depends on the business understanding

# %%
# go to univariate graphical analysis
# go to lesson : data visualisation 1 - chart type section
# then go to univariate graphical analysis
# detect outliers using graphs varbaly

# %%
# go to lesson: statistics 1 then statistics 3
# then go to univariate Non graphical analysis
# detect outliers using numerical statistics

# %%
# go to delete ouliers

# %% [markdown]
# ## 2. Data Cleaning:
#
# Preliminary findings from data profiling can lead to cleaning the data by:
# - Handling missing values
# - Correcting errors.
# - Dealing with outliers.
#
# -------------------

# %% [markdown]
# ### Handling missing values:

# %% [markdown]
# **Why my data has missing values?**
# They may occur at two stages:
# 1. Data Extraction: It is possible that there are problems with extraction process. Errors at data extraction stage are typically easy to find and can be corrected easily as well.
# 2. Data collection: These errors occur at time of data collection and are harder to correct.
#
# **Why do we need to handle the missing data?**
# To avoid:
# - Bias the conclusions.
# - Leading the business to make wrong decisions.
#
# **Which are the methods to treat missing values ?**
# 1. Deletion: we delete rows where any of the variable is missing. Simplicity is one of the major advantage of this method, but this method reduces the power of model because it reduces the sample size.
#
# 2. Imputation: is a method to fill in the missing values with estimated ones. This imputation is one of the most frequently used methods.
#
#     2.1. Mean/ Mode/ Median Imputation: It consists of replacing the missing data for a given attribute by the mean or median (quantitative attribute) or mode (qualitative attribute) of all known values of that variable.
#     > It can be of two types:
#     > - Generalized Imputation: In this case, we calculate the mean or median for all non missing values of that variable then replace missing value with mean or median.
#     > - Similar case Imputation: In this case, we calculate average for each group individually of non missing values then replace the missing value based on the group.
#
#     2.2. Constant Value
#
#     2.3. Forward Filling
#
#     2.4. Backward Filling
#
# 6. Prediction Model:  Prediction model is one of the sophisticated method for handling missing data. Here, we create a predictive model to estimate values that will substitute the missing data.  In this case, we divide our data set into two sets: One set with no missing values for the variable and another one with missing values. First data set become training data set of the model while second data set with missing values is test data set and variable with missing values is treated as target variable. Next, we create a model to predict target variable based on other attributes of the training data set and populate missing values of test data set.
#
# > There are 2 drawbacks for this approach:
# > - The model estimated values are usually more well-behaved than the true values
# > - If there are no relationships with attributes in the data set and the attribute with missing values, then the model will not be precise for estimating missing values.
#
# 9. KNN Imputation: In this method of imputation, the missing values of an attribute are imputed using the given number of attributes that are most similar to the attribute whose values are missing. The similarity of two attributes is determined using a distance function. It is also known to have certain advantage & disadvantages.
#
#    > **Advantages:**
#    > - k-nearest neighbour can predict both qualitative & quantitative attributes
#    > - Creation of predictive model for each attribute with missing data is not required
#    > - Attributes with multiple missing values can be easily treated
#    > - Correlation structure of the data is taken into consideration
#
#    > **Disadvantage:**
#    > - KNN algorithm is very time-consuming in analyzing large database. It searches through all the dataset looking for the most similar instances.
#    > - Choice of k-value is very critical. Higher value of k would include attributes which are significantly different from what we need whereas lower value of k implies missing out of significant attributes.
#
# --------------------

# %%
# go back to 6th dimention --> Completeness

# %% [markdown]
# ### Correcting errors
#
# -------------------

# %%
# go back to 7th dimension Accuracy

# %% [markdown]
# ### Dealing with outliers:

# %% [markdown]
# **How to remove Outliers?**
# Most of the ways to deal with outliers are similar to the methods of missing values like deleting rows, transforming them, binning them, treat them as a separate group, imputing values and other statistical methods. Here, we will discuss the common techniques used to deal with outliers:
#
# 1. Deleting rows: We delete outlier values if it is due to data entry error, data processing error or outlier rows are very small in numbers. We can also use trimming at both ends to remove outliers.
#
# 2. Imputing: Like imputation of missing values, we can also impute outliers. We can use mean, median, mode imputation methods. Before imputing values, we should analyse if it is natural outlier or artificial. If it is artificial, we can go with imputing values. We can also use statistical model to predict values of outlier rows and after that we can impute it with predicted values.
#
# 3. Treat separately: If there are significant number of outliers, we should treat them separately in the statistical model. One of the approach is to treat both groups as two different groups and build individual model for both groups and then combine the output.

# %% [markdown]
# ## 3. Univariate Analysis:
#
# This involves examining single variables to understand their characteristics (distribution, central tendency, dispersion, and shape).
#
# We calculate **numerical values** about the data that tells us about the distribution of the data. We also **draw graphs** showing visually how the data is distributed. **To answer the following questions about Features/characteristics of Data:**
# - Where is the center of the data? (location)
# - How much does the data vary? (scale)
# - What is the shape of the data? (shape)
#
# **The benefits of this analysis:**
# Statistics summary gives a high-level idea to identify whether the data has any outliers, data entry error, distribution of data such as the data is normally distributed or left/right skewed
#
# **In this step, we will explore variables one by one using following approaches:**

# %% [markdown]
# ### 1. Univariate Graphical Analysis:
# Method to perform uni-variate analysis will depend on whether the variable type is categorical or numerical.

# %% [markdown]
# #### I. Categorical Variables:
#
# we’ll use frequency table to understand distribution of each category
# - Bar Chart (Ordinal) - Orderd
# - Pie Chart (Nominal) - non Orderd

# %% [markdown]
# #### II. Numerical Variables:
#
# we need to understand the central tendency and spread of the variable (Descriptive Analysis) using:
#    - Box plot
#    - Histogram

# %% [markdown]
# ### 2. Univariate Non-Graphical analysis:
#
# - Where is the center of the data? (location) --> **Measures of central tendency**
# - How much does the data vary? (scale) --> **Measure of variability**
# - What is the shape of the data? (shape) --> **Measures of variation combined with an average (measure of center) gives a good picture of the distribution of the data.**

# %% [markdown]
# ## 4. Bivariate/Multivariate Analysis:
#
# Here, you look at the relationships between two or more variables. This can involve looking for correlations, patterns, and trends that suggest a relationship or an association.
#
# We can perform bi-variate analysis for any combination of categorical and numerical variables. The combination can be:
# | bi-variate variables   | Plot type |
# | ------------- | ------------- |
# | Categorical & Categorical| Stacked Bar Chart |
# | Categorical & numerical  | scatter plot, histogram, box plot|
# | numerical  & numerical  | Scatter plot, line chart|
#
#
# Multivariate Analysis:
# - Heat map
# - Bar Chart
# - Scatter Chart
# - Line Chart

# %% [markdown]
# **Categorical & Categorical --> (Stacked Column Chart)**

# %% [markdown]
# **Categorical & numerical --> (scatter plot, histogram, box plot)**

# %% [markdown]
# **numerical & numerical --> (Scatter plot, line chart)**

# %% [markdown]
# We could also use a correlation matrix to get more specific information about the relationship between these two variables.
